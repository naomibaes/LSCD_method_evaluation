# %% [markdown]
# # Plot Sentiment Index (Baseline)
#
# Authors: Naomi Baes and Chat GPT
#
# The script processes linguistic data by generating samples that combine natural sentences and synthetic variations (both positive and negative) across predefined time intervals for specified target terms. It handles sampling without replacement within each batch to ensure diversity and integrity, and saves the mixed samples into separate directories based on the variation type, applying different injection ratios to simulate varying levels of synthetic data integration for linguistic analysis.

# %% [markdown]
# ## 5-year Sentiment Index

# %%
#%run step4_baseline_plot_5-year_sentiment-index_POS.py

# %%
#%run step4_baseline_plot_5-year_sentiment-index_NEG.py

# %%
# %run step4_baseline_plot_5-year_sentiment-index_BOTH.py
# Out:
# Successfully read data from CSV file.

# %%
# %run step4_baseline_plot_5-year_sentiment-index_BOTH_normalized.py
# Out:
# Successfully read data from CSV file.

# %% [markdown]
# ## all-year Sentiment Index

# %%
# %run step4_baseline_plot_all-year_sentiment-index_BOTH_SE.py # raw index
# Out:
# C:\Users\naomi\OneDrive\COMP80004_PhDResearch\RESEARCH\PROJECTS\3_evaluation+validation - ACL 2025\ICL\1_sentiment\step4_baseline_plot_all-year_sentiment-index_BOTH_SE.py:57: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-" (-> linestyle='-'). The keyword argument will take precedence.
#
# C:\Users\naomi\OneDrive\COMP80004_PhDResearch\RESEARCH\PROJECTS\3_evaluation+validation - ACL 2025\ICL\1_sentiment\step4_baseline_plot_all-year_sentiment-index_BOTH_SE.py:57: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-" (-> marker='o'). The keyword argument will take precedence.
#
# ...

# %%
# %run step4_baseline_plot_all-year_sentiment-index_BOTH_SE_normalized.py
# Out:
# C:\Users\naomi\OneDrive\COMP80004_PhDResearch\RESEARCH\PROJECTS\3_evaluation+validation - ACL 2025\ICL\1_sentiment\step4_baseline_plot_all-year_sentiment-index_BOTH_SE_normalized.py:62: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-" (-> linestyle='-'). The keyword argument will take precedence.
#
# C:\Users\naomi\OneDrive\COMP80004_PhDResearch\RESEARCH\PROJECTS\3_evaluation+validation - ACL 2025\ICL\1_sentiment\step4_baseline_plot_all-year_sentiment-index_BOTH_SE_normalized.py:62: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-" (-> marker='o'). The keyword argument will take precedence.
#
# ...

# %% [markdown]
# # Plot Sentiment Index (ABSA)

# %% [markdown]
# ## 5-year Sentiment Index

# %%
# %run step4_absa_plot_5-year_sentiment-index_BOTH.py
# Out:
# Successfully read data from CSV file.

# %% [markdown]
# ## all-year Sentiment Index

# %%
# %run step4_absa_plot_all-year_sentiment-index_BOTH_SE.py
# Out:
# C:\Users\naomi\OneDrive\COMP80004_PhDResearch\RESEARCH\PROJECTS\3_evaluation+validation - ACL 2025\ICL\1_sentiment\step4_absa_plot_all-year_sentiment-index_BOTH_SE.py:49: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-" (-> linestyle='-'). The keyword argument will take precedence.
#   linestyle=line_styles[term], marker=marker_style[term], markersize=14, linewidth=3)
# C:\Users\naomi\OneDrive\COMP80004_PhDResearch\RESEARCH\PROJECTS\3_evaluation+validation - ACL 2025\ICL\1_sentiment\step4_absa_plot_all-year_sentiment-index_BOTH_SE.py:49: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-" (-> marker='o'). The keyword argument will take precedence.
#   linestyle=line_styles[term], marker=marker_style[term], markersize=14, linewidth=3)
# ...

# %% [markdown]
# # End of script

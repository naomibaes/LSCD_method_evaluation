# %% [markdown]
# # Compute Sentiment Index (ABSA)
#
# Author: Raphael Merx

# %% [markdown]
# Original: https://huggingface.co/MoritzLaurer/deberta-v3-large-zeroshot-v2.0
# ABSA variant: https://huggingface.co/yangheng/deberta-v3-base-absa-v1.1

# %% [markdown]
# ## 5-year Sentiment Index

# %%
# %run step1_absa_sentiment_5-year.py
# Out:
# c:\Users\naomi\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# 100%|██████████| 60/60 [00:46<00:00,  1.29it/s]

# %% [markdown]
# ### Plot

# %%
# plot sentiment indices with positive sentiment synthetic injections
# %run step4_absa_plot_5-year_sentiment-index_POS.py
# Out:
# Successfully read data from CSV file.

# %%
# plot sentiment indices with negative sentiment synthetic injections
# %run step4_absa_plot_5-year_sentiment-index_NEG.py
# Out:
# Successfully read data from CSV file.

# %%
# plot sentiment indices with positive and negative sentiment synthetic injections
# %run step4_absa_plot_5-year_sentiment-index_BOTH.py
# Out:
# Successfully read data from CSV file.

# %% [markdown]
# ## all-year Sentiment Index

# %%
## include script for computing sentiment index for all-year samples

# %% [markdown]
# ### Plot

# %%
# plot sentiment indices with positive sentiment synthetic injections
# %run step4_absa_plot_all-year_sentiment-index_POS.py
# Out:
# Successfully read data from CSV file.

# %%
# plot sentiment indices with negative sentiment synthetic injections
# %run step4_absa_plot_all-year_sentiment-index_NEG.py
# Out:
# Successfully read data from CSV file.

# %%
# plot sentiment indices with positive and negative sentiment synthetic injections
# %run step4_absa_plot_all-year_sentiment-index_BOTH.py
# Out:
# C:\Users\naomi\OneDrive\COMP80004_PhDResearch\RESEARCH\PROJECTS\3_evaluation+validation - ACL 2025\ICL\1_sentiment\step4_plot_all-year_sentiment-index_BOTH.py:106: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %% [markdown]
# # End of script

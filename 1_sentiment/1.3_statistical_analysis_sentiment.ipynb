# %% [markdown]
# # Statistical Analysis
#
# Authors: Naomi Baes and Chat GPT

# %% [markdown]
# ## APD

# %%
# %run step5_baseline_APD_analysis_5-year.py
# Out:
# c:\Users\naomi\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# Successfully read data from CSV file.
# Positive Valence APD:
#              Term         0        20        40        60        80       100
# 0           abuse  5.304623  5.365098  5.421544  5.466736  5.519245  5.605549
# 1         anxiety  5.173116  5.234412  5.301330  5.371444  5.420379  5.488560
# 2      depression  5.157802  5.221488  5.295465  5.351103  5.418109  5.477814
# 3   mental_health  5.585507  5.643076  5.703986  5.760999  5.815156  5.868744
# 4  mental_illness  5.376198  5.443374  5.514368  5.589131  5.665019  5.734439
# 5          trauma  5.233352  5.307619  5.357179  5.410020  5.473221  5.537159
#
# Negative Valence APD:
#              Term         0        20        40        60        80       100
# 0           abuse  5.304623  5.265875  5.237845  5.196028  5.153269  5.110017
# 1         anxiety  5.173116  5.150851  5.130162  5.116039  5.083812  5.073043
# 2      depression  5.157802  5.133266  5.116424  5.090301  5.074137  5.053441
# 3   mental_health  5.585507  5.545559  5.513570  5.474043  5.436590  5.402534
# 4  mental_illness  5.376198  5.327625  5.236376  5.253433  5.169023  5.128982
# 5          trauma  5.233352  5.192285  5.167652  5.144115  5.121345  5.067605

# %%
# %run step5_baseline_APD_analysis_all-year.py

# %% [markdown]
# ## MEM (positive)

# %%
# %run step6_baseline_5-year_mem_analysis_positive.py
# Out:
# Null Model Summary:
#                  Mixed Linear Model Regression Results
# ========================================================================
# Model:            MixedLM Dependent Variable: avg_valence_index_positive
# No. Observations: 360     Method:             REML
# No. Groups:       6       Scale:              0.0153
# Min. group size:  60      Log-Likelihood:     226.8560
# Max. group size:  60      Converged:          Yes
# Mean group size:  60.0
# ----------------------------------------------------------------------------
#                Coef.     Std.Err.       z        P>|z|     [0.025     0.975]
# ----------------------------------------------------------------------------
# Intercept      5.461        0.064     85.279     0.000      5.336      5.587
# Group Var      0.024        0.127
# ========================================================================
#
# ICC for 'target': 0.6146047871549624
# Full Model Summary:
#                  Mixed Linear Model Regression Results
# ========================================================================
# Model:            MixedLM Dependent Variable: avg_valence_index_positive
# No. Observations: 360     Method:             REML
# No. Groups:       6       Scale:              0.0039
# Min. group size:  60      Log-Likelihood:     453.9192
# Max. group size:  60      Converged:          Yes
# Mean group size:  60.0
# -------------------------------------------------------------------------
#                            Coef.  Std.Err.    z     P>|z|  [0.025  0.975]
# -------------------------------------------------------------------------
# Intercept                  5.305     0.064  82.302  0.000   5.179   5.431
# injection_ratio[T.20]      0.064     0.011   5.645  0.000   0.042   0.086
# injection_ratio[T.40]      0.127     0.011  11.207  0.000   0.105   0.149
# injection_ratio[T.60]      0.186     0.011  16.428  0.000   0.164   0.209
# injection_ratio[T.80]      0.247     0.011  21.739  0.000   0.225   0.269
# injection_ratio[T.100]     0.314     0.011  27.629  0.000   0.291   0.336
# Group Var                  0.025     0.252
# ========================================================================
#
# Model with Epoch Summary:
#                        Mixed Linear Model Regression Results
# ====================================================================================
# Model:                MixedLM     Dependent Variable:     avg_valence_index_positive
# No. Observations:     360         Method:                 REML
# No. Groups:           6           Scale:                  0.0041
# Min. group size:      60          Log-Likelihood:         331.6104
# Max. group size:      60          Converged:              Yes
# Mean group size:      60.0
# ------------------------------------------------------------------------------------
#                                           Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------------------------------
# Intercept                                  5.288    0.069 76.586 0.000  5.153  5.423
# injection_ratio[T.20]                      0.059    0.037  1.594 0.111 -0.013  0.131
# injection_ratio[T.40]                      0.107    0.037  2.920 0.004  0.035  0.180
# injection_ratio[T.60]                      0.146    0.037  3.970 0.000  0.074  0.218
# injection_ratio[T.80]                      0.203    0.037  5.503 0.000  0.130  0.275
# injection_ratio[T.100]                     0.300    0.037  8.146 0.000  0.228  0.372
# epoch[T.1975-1979]                         0.026    0.037  0.694 0.488 -0.047  0.098
# epoch[T.1980-1984]                         0.047    0.037  1.283 0.199 -0.025  0.119
# epoch[T.1985-1989]                         0.039    0.037  1.069 0.285 -0.033  0.112
# epoch[T.1990-1994]                         0.027    0.037  0.741 0.459 -0.045  0.099
# epoch[T.1995-1999]                         0.037    0.037  0.996 0.319 -0.035  0.109
# epoch[T.2000-2004]                        -0.026    0.037 -0.704 0.481 -0.098  0.046
# epoch[T.2005-2009]                        -0.006    0.037 -0.156 0.876 -0.078  0.066
# epoch[T.2010-2014]                         0.006    0.037  0.158 0.874 -0.066  0.078
# epoch[T.2015-2019]                         0.020    0.037  0.536 0.592 -0.052  0.092
# injection_ratio[T.20]:epoch[T.1975-1979]   0.003    0.052  0.050 0.960 -0.099  0.105
# injection_ratio[T.40]:epoch[T.1975-1979]   0.007    0.052  0.137 0.891 -0.095  0.109
# injection_ratio[T.60]:epoch[T.1975-1979]   0.030    0.052  0.570 0.569 -0.072  0.132
# injection_ratio[T.80]:epoch[T.1975-1979]   0.033    0.052  0.632 0.527 -0.069  0.135
# injection_ratio[T.100]:epoch[T.1975-1979]  0.008    0.052  0.151 0.880 -0.094  0.110
# injection_ratio[T.20]:epoch[T.1980-1984]  -0.003    0.052 -0.050 0.960 -0.105  0.099
# injection_ratio[T.40]:epoch[T.1980-1984]  -0.002    0.052 -0.038 0.970 -0.104  0.100
# injection_ratio[T.60]:epoch[T.1980-1984]   0.007    0.052  0.132 0.895 -0.095  0.109
# injection_ratio[T.80]:epoch[T.1980-1984]   0.007    0.052  0.128 0.898 -0.095  0.109
# injection_ratio[T.100]:epoch[T.1980-1984] -0.035    0.052 -0.674 0.500 -0.137  0.067
# injection_ratio[T.20]:epoch[T.1985-1989]   0.005    0.052  0.097 0.923 -0.097  0.107
# injection_ratio[T.40]:epoch[T.1985-1989]   0.025    0.052  0.476 0.634 -0.077  0.127
# injection_ratio[T.60]:epoch[T.1985-1989]   0.045    0.052  0.862 0.389 -0.057  0.147
# injection_ratio[T.80]:epoch[T.1985-1989]   0.049    0.052  0.933 0.351 -0.053  0.151
# injection_ratio[T.100]:epoch[T.1985-1989]  0.002    0.052  0.034 0.973 -0.100  0.104
# injection_ratio[T.20]:epoch[T.1990-1994]   0.012    0.052  0.227 0.821 -0.090  0.114
# injection_ratio[T.40]:epoch[T.1990-1994]   0.025    0.052  0.482 0.630 -0.077  0.127
# injection_ratio[T.60]:epoch[T.1990-1994]   0.049    0.052  0.941 0.347 -0.053  0.151
# injection_ratio[T.80]:epoch[T.1990-1994]   0.049    0.052  0.939 0.348 -0.053  0.151
# injection_ratio[T.100]:epoch[T.1990-1994]  0.020    0.052  0.377 0.706 -0.082  0.122
# injection_ratio[T.20]:epoch[T.1995-1999]   0.004    0.052  0.082 0.935 -0.098  0.106
# injection_ratio[T.40]:epoch[T.1995-1999]   0.013    0.052  0.249 0.804 -0.089  0.115
# injection_ratio[T.60]:epoch[T.1995-1999]   0.031    0.052  0.601 0.548 -0.071  0.133
# injection_ratio[T.80]:epoch[T.1995-1999]   0.035    0.052  0.667 0.505 -0.067  0.137
# injection_ratio[T.100]:epoch[T.1995-1999]  0.007    0.052  0.139 0.890 -0.095  0.109
# injection_ratio[T.20]:epoch[T.2000-2004]   0.007    0.052  0.131 0.896 -0.095  0.109
# injection_ratio[T.40]:epoch[T.2000-2004]   0.042    0.052  0.809 0.419 -0.060  0.144
# injection_ratio[T.60]:epoch[T.2000-2004]   0.088    0.052  1.688 0.091 -0.014  0.190
# injection_ratio[T.80]:epoch[T.2000-2004]   0.099    0.052  1.892 0.058 -0.004  0.201
# injection_ratio[T.100]:epoch[T.2000-2004]  0.077    0.052  1.485 0.138 -0.025  0.179
# injection_ratio[T.20]:epoch[T.2005-2009]   0.020    0.052  0.375 0.707 -0.083  0.122
# injection_ratio[T.40]:epoch[T.2005-2009]   0.037    0.052  0.702 0.483 -0.065  0.139
# injection_ratio[T.60]:epoch[T.2005-2009]   0.063    0.052  1.206 0.228 -0.039  0.165
# injection_ratio[T.80]:epoch[T.2005-2009]   0.067    0.052  1.295 0.195 -0.035  0.169
# injection_ratio[T.100]:epoch[T.2005-2009]  0.039    0.052  0.740 0.459 -0.064  0.141
# injection_ratio[T.20]:epoch[T.2010-2014]   0.001    0.052  0.016 0.987 -0.101  0.103
# injection_ratio[T.40]:epoch[T.2010-2014]   0.025    0.052  0.483 0.629 -0.077  0.127
# injection_ratio[T.60]:epoch[T.2010-2014]   0.038    0.052  0.735 0.462 -0.064  0.140
# injection_ratio[T.80]:epoch[T.2010-2014]   0.048    0.052  0.922 0.357 -0.054  0.150
# injection_ratio[T.100]:epoch[T.2010-2014]  0.006    0.052  0.110 0.912 -0.096  0.108
# injection_ratio[T.20]:epoch[T.2015-2019]   0.006    0.052  0.109 0.914 -0.096  0.108
# injection_ratio[T.40]:epoch[T.2015-2019]   0.026    0.052  0.490 0.624 -0.077  0.128
# injection_ratio[T.60]:epoch[T.2015-2019]   0.053    0.052  1.008 0.313 -0.050  0.155
# injection_ratio[T.80]:epoch[T.2015-2019]   0.056    0.052  1.080 0.280 -0.046  0.158
# injection_ratio[T.100]:epoch[T.2015-2019]  0.014    0.052  0.278 0.781 -0.088  0.117
# Group Var                                  0.025    0.246
# ====================================================================================
#
# Likelihood Ratio Test Statistic: -244.61754614084828, p-value: 1.0
# Shapiro-Wilk test for normality: Statistic=0.8378129601478577, p-value=8.78685737176678e-19
# Levene’s test for homogeneity of variances: Statistic=0.9784476931009842, p-value=0.3229155668645737
# OLS Model Summary:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     avg_valence_index_positive   R-squared:                       0.317
# Model:                                    OLS   Adj. R-squared:                  0.308
# Method:                         Least Squares   F-statistic:                     32.90
# Date:                        Tue, 14 Jan 2025   Prob (F-statistic):           1.51e-27
# Time:                                18:25:00   Log-Likelihood:                 158.63
# No. Observations:                         360   AIC:                            -305.3
# Df Residuals:                             354   BIC:                            -281.9
# Df Model:                                   5
# Covariance Type:                    nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  5.3051      0.020    261.649      0.000       5.265       5.345
# injection_ratio[T.20]      0.0641      0.029      2.235      0.026       0.008       0.120
# injection_ratio[T.40]      0.1272      0.029      4.436      0.000       0.071       0.184
# injection_ratio[T.60]      0.1865      0.029      6.503      0.000       0.130       0.243
# injection_ratio[T.80]      0.2468      0.029      8.606      0.000       0.190       0.303
# injection_ratio[T.100]     0.3136      0.029     10.937      0.000       0.257       0.370
# ==============================================================================
# Omnibus:                       18.357   Durbin-Watson:                   0.146
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               15.114
# Skew:                           0.417   Prob(JB):                     0.000522
# Kurtosis:                       2.442   Cond. No.                         6.85
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## MEM (negative)

# %%
# %run step6_baseline_5-year_mem_analysis_negative.py
# Out:
# Null Model Summary:
#                  Mixed Linear Model Regression Results
# ========================================================================
# Model:            MixedLM Dependent Variable: avg_valence_index_negative
# No. Observations: 360     Method:             REML
# No. Groups:       6       Scale:              0.0104
# Min. group size:  60      Log-Likelihood:     295.7860
# Max. group size:  60      Converged:          Yes
# Mean group size:  60.0
# ----------------------------------------------------------------------------
#                Coef.     Std.Err.       z        P>|z|     [0.025     0.975]
# ----------------------------------------------------------------------------
# Intercept      5.222        0.059     89.196     0.000      5.107      5.337
# Group Var      0.020        0.129
# ========================================================================
#
# ICC for 'target': 0.6628722074402831
# Full Model Summary:
#                  Mixed Linear Model Regression Results
# ========================================================================
# Model:            MixedLM Dependent Variable: avg_valence_index_negative
# No. Observations: 360     Method:             REML
# No. Groups:       6       Scale:              0.0073
# Min. group size:  60      Log-Likelihood:     342.9044
# Max. group size:  60      Converged:          Yes
# Mean group size:  60.0
# -------------------------------------------------------------------------
#                          Coef.   Std.Err.     z     P>|z|  [0.025  0.975]
# -------------------------------------------------------------------------
# Intercept                 5.305     0.059   89.294  0.000   5.189   5.422
# injection_ratio[T.20]    -0.036     0.016   -2.295  0.022  -0.066  -0.005
# injection_ratio[T.40]    -0.071     0.016   -4.572  0.000  -0.102  -0.041
# injection_ratio[T.60]    -0.093     0.016   -5.939  0.000  -0.123  -0.062
# injection_ratio[T.80]    -0.132     0.016   -8.454  0.000  -0.163  -0.101
# injection_ratio[T.100]   -0.166     0.016  -10.615  0.000  -0.196  -0.135
# Group Var                 0.020     0.153
# ========================================================================
#
# Model with Epoch Summary:
#                        Mixed Linear Model Regression Results
# ====================================================================================
# Model:                MixedLM     Dependent Variable:     avg_valence_index_negative
# No. Observations:     360         Method:                 REML
# No. Groups:           6           Scale:                  0.0068
# Min. group size:      60          Log-Likelihood:         255.8539
# Max. group size:      60          Converged:              Yes
# Mean group size:      60.0
# ------------------------------------------------------------------------------------
#                                           Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------------------------------
# Intercept                                  5.288    0.067 78.443 0.000  5.156  5.420
# injection_ratio[T.20]                     -0.069    0.048 -1.454 0.146 -0.163  0.024
# injection_ratio[T.40]                     -0.181    0.048 -3.800 0.000 -0.275 -0.088
# injection_ratio[T.60]                     -0.125    0.048 -2.626 0.009 -0.219 -0.032
# injection_ratio[T.80]                     -0.245    0.048 -5.133 0.000 -0.338 -0.151
# injection_ratio[T.100]                    -0.328    0.048 -6.873 0.000 -0.421 -0.234
# epoch[T.1975-1979]                         0.026    0.048  0.536 0.592 -0.068  0.119
# epoch[T.1980-1984]                         0.047    0.048  0.991 0.322 -0.046  0.141
# epoch[T.1985-1989]                         0.039    0.048  0.826 0.409 -0.054  0.133
# epoch[T.1990-1994]                         0.027    0.048  0.572 0.567 -0.066  0.121
# epoch[T.1995-1999]                         0.037    0.048  0.769 0.442 -0.057  0.130
# epoch[T.2000-2004]                        -0.026    0.048 -0.544 0.586 -0.119  0.067
# epoch[T.2005-2009]                        -0.006    0.048 -0.121 0.904 -0.099  0.088
# epoch[T.2010-2014]                         0.006    0.048  0.122 0.903 -0.088  0.099
# epoch[T.2015-2019]                         0.020    0.048  0.414 0.679 -0.074  0.113
# injection_ratio[T.20]:epoch[T.1975-1979]   0.028    0.067  0.412 0.680 -0.104  0.160
# injection_ratio[T.40]:epoch[T.1975-1979]   0.119    0.067  1.758 0.079 -0.014  0.251
# injection_ratio[T.60]:epoch[T.1975-1979]   0.041    0.067  0.605 0.545 -0.091  0.173
# injection_ratio[T.80]:epoch[T.1975-1979]   0.126    0.067  1.863 0.062 -0.007  0.258
# injection_ratio[T.100]:epoch[T.1975-1979]  0.171    0.067  2.542 0.011  0.039  0.303
# injection_ratio[T.20]:epoch[T.1980-1984]   0.039    0.067  0.577 0.564 -0.093  0.171
# injection_ratio[T.40]:epoch[T.1980-1984]   0.110    0.067  1.626 0.104 -0.023  0.242
# injection_ratio[T.60]:epoch[T.1980-1984]   0.014    0.067  0.208 0.835 -0.118  0.146
# injection_ratio[T.80]:epoch[T.1980-1984]   0.101    0.067  1.504 0.133 -0.031  0.233
# injection_ratio[T.100]:epoch[T.1980-1984]  0.151    0.067  2.240 0.025  0.019  0.283
# injection_ratio[T.20]:epoch[T.1985-1989]   0.032    0.067  0.482 0.630 -0.100  0.165
# injection_ratio[T.40]:epoch[T.1985-1989]   0.112    0.067  1.657 0.098 -0.020  0.244
# injection_ratio[T.60]:epoch[T.1985-1989]   0.030    0.067  0.441 0.659 -0.102  0.162
# injection_ratio[T.80]:epoch[T.1985-1989]   0.120    0.067  1.773 0.076 -0.013  0.252
# injection_ratio[T.100]:epoch[T.1985-1989]  0.158    0.067  2.347 0.019  0.026  0.290
# injection_ratio[T.20]:epoch[T.1990-1994]   0.034    0.067  0.511 0.609 -0.098  0.167
# injection_ratio[T.40]:epoch[T.1990-1994]   0.118    0.067  1.745 0.081 -0.015  0.250
# injection_ratio[T.60]:epoch[T.1990-1994]   0.031    0.067  0.460 0.646 -0.101  0.163
# injection_ratio[T.80]:epoch[T.1990-1994]   0.120    0.067  1.778 0.075 -0.012  0.252
# injection_ratio[T.100]:epoch[T.1990-1994]  0.177    0.067  2.621 0.009  0.045  0.309
# injection_ratio[T.20]:epoch[T.1995-1999]   0.036    0.067  0.538 0.591 -0.096  0.168
# injection_ratio[T.40]:epoch[T.1995-1999]   0.114    0.067  1.696 0.090 -0.018  0.246
# injection_ratio[T.60]:epoch[T.1995-1999]   0.020    0.067  0.295 0.768 -0.112  0.152
# injection_ratio[T.80]:epoch[T.1995-1999]   0.114    0.067  1.698 0.089 -0.018  0.247
# injection_ratio[T.100]:epoch[T.1995-1999]  0.175    0.067  2.591 0.010  0.043  0.307
# injection_ratio[T.20]:epoch[T.2000-2004]   0.037    0.067  0.553 0.580 -0.095  0.169
# injection_ratio[T.40]:epoch[T.2000-2004]   0.132    0.067  1.959 0.050 -0.000  0.264
# injection_ratio[T.60]:epoch[T.2000-2004]   0.063    0.067  0.929 0.353 -0.070  0.195
# injection_ratio[T.80]:epoch[T.2000-2004]   0.158    0.067  2.344 0.019  0.026  0.290
# injection_ratio[T.100]:epoch[T.2000-2004]  0.230    0.067  3.411 0.001  0.098  0.362
# injection_ratio[T.20]:epoch[T.2005-2009]   0.052    0.067  0.768 0.443 -0.080  0.184
# injection_ratio[T.40]:epoch[T.2005-2009]   0.138    0.067  2.047 0.041  0.006  0.270
# injection_ratio[T.60]:epoch[T.2005-2009]   0.051    0.067  0.756 0.450 -0.081  0.183
# injection_ratio[T.80]:epoch[T.2005-2009]   0.133    0.067  1.971 0.049  0.001  0.265
# injection_ratio[T.100]:epoch[T.2005-2009]  0.197    0.067  2.925 0.003  0.065  0.329
# injection_ratio[T.20]:epoch[T.2010-2014]   0.036    0.067  0.539 0.590 -0.096  0.168
# injection_ratio[T.40]:epoch[T.2010-2014]   0.128    0.067  1.904 0.057 -0.004  0.260
# injection_ratio[T.60]:epoch[T.2010-2014]   0.033    0.067  0.491 0.624 -0.099  0.165
# injection_ratio[T.80]:epoch[T.2010-2014]   0.124    0.067  1.839 0.066 -0.008  0.256
# injection_ratio[T.100]:epoch[T.2010-2014]  0.174    0.067  2.575 0.010  0.041  0.306
# injection_ratio[T.20]:epoch[T.2015-2019]   0.039    0.067  0.583 0.560 -0.093  0.171
# injection_ratio[T.40]:epoch[T.2015-2019]   0.127    0.067  1.882 0.060 -0.005  0.259
# injection_ratio[T.60]:epoch[T.2015-2019]   0.042    0.067  0.621 0.534 -0.090  0.174
# injection_ratio[T.80]:epoch[T.2015-2019]   0.130    0.067  1.933 0.053 -0.002  0.262
# injection_ratio[T.100]:epoch[T.2015-2019]  0.185    0.067  2.748 0.006  0.053  0.317
# Group Var                                  0.020    0.159
# ====================================================================================
#
# Likelihood Ratio Test Statistic: -174.10085118709242, p-value: 1.0
# Shapiro-Wilk test for normality: Statistic=0.7431643009185791, p-value=3.093240991874284e-23
# Levene’s test for homogeneity of variances: Statistic=7.166840027937802, p-value=0.007595930529219111
# OLS Model Summary:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     avg_valence_index_negative   R-squared:                       0.113
# Model:                                    OLS   Adj. R-squared:                  0.101
# Method:                         Least Squares   F-statistic:                     9.059
# Date:                        Tue, 14 Jan 2025   Prob (F-statistic):           4.05e-08
# Time:                                18:25:10   Log-Likelihood:                 158.74
# No. Observations:                         360   AIC:                            -305.5
# Df Residuals:                             354   BIC:                            -282.2
# Df Model:                                   5
# Covariance Type:                    nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  5.3051      0.020    261.732      0.000       5.265       5.345
# injection_ratio[T.20]     -0.0359      0.029     -1.251      0.212      -0.092       0.021
# injection_ratio[T.40]     -0.0714      0.029     -2.492      0.013      -0.128      -0.015
# injection_ratio[T.60]     -0.0928      0.029     -3.236      0.001      -0.149      -0.036
# injection_ratio[T.80]     -0.1321      0.029     -4.607      0.000      -0.188      -0.076
# injection_ratio[T.100]    -0.1658      0.029     -5.785      0.000      -0.222      -0.109
# ==============================================================================
# Omnibus:                        5.734   Durbin-Watson:                   0.359
# Prob(Omnibus):                  0.057   Jarque-Bera (JB):                6.324
# Skew:                           0.190   Prob(JB):                       0.0423
# Kurtosis:                       3.526   Cond. No.                         6.85
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

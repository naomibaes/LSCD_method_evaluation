# %% [markdown]
# # Statistical Analysis
#
# Authors: Naomi Baes and Chat GPT

# %% [markdown]
# ## Simple linear regression (positive)

# %%
#%run step6_baseline_all-year_ols_analysis_positive.py

# %% [markdown]
# ## MEM (positive)

# %%
# %run step6_baseline_all-year_mem_analysis_positive.py
# Out:
# Null Model Summary:
#                  Mixed Linear Model Regression Results
# ...
# Model:            MixedLM Dependent Variable: avg_valence_index_positive
# No. Observations: 36      Method:             REML
# No. Groups:       6       Scale:              0.0163
# Min. group size:  6       Log-Likelihood:     14.9332
# Max. group size:  6       Converged:          Yes
# Mean group size:  6.0
# ----------------------------------------------------------------------------
#                Coef.     Std.Err.       z        P>|z|     [0.025     0.975]
# ----------------------------------------------------------------------------
# Intercept      5.450        0.066     83.077     0.000      5.321      5.578
# Group Var      0.023        0.138
# ...
#
# ICC for 'target': 0.5858810555651264
# Simplified Model with Random Intercepts Summary:
#                  Mixed Linear Model Regression Results
# ...
# Model:            MixedLM Dependent Variable: avg_valence_index_positive
# ...

# %%
#%run step6_baseline_5-year_mem_analysis_positive.py

# %% [markdown]
# ## MEM (negative)

# %%
# %run step6_baseline_all-year_mem_analysis_negative.py
# Out:
# Null Model Summary:
#                  Mixed Linear Model Regression Results
# ...
# Model:            MixedLM Dependent Variable: avg_valence_index_negative
# No. Observations: 36      Method:             REML
# No. Groups:       6       Scale:              0.0027
# Min. group size:  6       Log-Likelihood:     42.5387
# Max. group size:  6       Converged:          Yes
# Mean group size:  6.0
# ----------------------------------------------------------------------------
#                Coef.     Std.Err.       z        P>|z|     [0.025     0.975]
# ----------------------------------------------------------------------------
# Intercept      5.215        0.059     88.363     0.000      5.100      5.331
# Group Var      0.020        0.276
# ...
#
# ICC for 'target': 0.8839752773873232
# Simplified Model with Random Intercepts Summary:
#                  Mixed Linear Model Regression Results
# ...
# Model:            MixedLM Dependent Variable: avg_valence_index_negative
# ...

# %%
#%run step6_baseline_5-year_mem_analysis_negative.py

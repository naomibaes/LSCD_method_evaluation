# %% [markdown]
# # Control analysis
#
# Authors: Naomi Baes and Chat GPT

# %% [markdown]
# ## 5-year random stratified random sampling strategy

# %%
# Get sentences from 5-year samples and put in one files grouped by condition, target, epoch
# %run step7.1_control_shuffle_5-year.py
# Out:
# Files have been successfully grouped, split by natural and synthetic, and saved.

# %%
# The script generates randomized uniform samples of natural and synthetic sentences for specified targets, time intervals, and conditions, saving the results into separate 
# files without column headers and differentiating injection ratio rounds in the file names for later aggregation.
# %run step7.2_control_randomly_sample_sentences_5-year.py
# Out:
# 100%|██████████| 60/60 [00:08<00:00,  7.24it/s]

# %%
# %run step7.3_control_process_sentences_5-year.cosine_mpnet.py
# Out:
# c:\Users\naomi\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:1150: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\naomi\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:1150: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing directory: output/5-year.cosine/control
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.1.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.58s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.1.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.10.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.08s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.10.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.2.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.18it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.2.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.3.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.01s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.3.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.4.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.02it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.4.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.5.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.5.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.6.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.02it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.6.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.7.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.02it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.7.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.8.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.00s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.8.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.9.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.13s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.9.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.1.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.10s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.1.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.10.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.15s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.10.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.2.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.02it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.2.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.3.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.08s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.3.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.4.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.08s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.4.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.5.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.04it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.5.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.6.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.59s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.6.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.7.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.60s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.7.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.8.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.00s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.8.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.9.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.22s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.9.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.1.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.22s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.1.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.10.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.37s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.10.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.2.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.47s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.2.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.3.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.39s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.3.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.4.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.11s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.4.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.5.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.10s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.5.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.6.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.27s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.6.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.7.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.22s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.7.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.8.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.15s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.8.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.9.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.57s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.9.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.1.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.13s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.1.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.10.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.36s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.10.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.2.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.12s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.2.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.3.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.30s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.3.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.4.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.26s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.4.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.5.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.07s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.5.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.6.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.12s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.6.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.7.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.12s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.7.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.8.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.21s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.8.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.9.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.55s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.9.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.1.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.16s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.1.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.10.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.41s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.10.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.2.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.22s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.2.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.3.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.46s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.3.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.4.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.22s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.4.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.5.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.12s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.5.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.6.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.29s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.6.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.7.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.19s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.7.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.8.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.23s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.8.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.9.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.36s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.9.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.1.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.42s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.1.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.10.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.34s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.10.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.2.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.14s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.2.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.3.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.24s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.3.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.4.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.22s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.4.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.5.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.13s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.5.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.6.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.16s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.6.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.7.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.20s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.7.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.8.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.27s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.8.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.9.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.33s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.9.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.1.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.07s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.1.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.10.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.25s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.10.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.2.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.23it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.2.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.3.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.07it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.3.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.4.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.75s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.4.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.5.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.22it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.5.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.6.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.38s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.6.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.7.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.7.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.8.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.00s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.8.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.9.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.9.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round2.1.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.04it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round2.1.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round2.10.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.06s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round2.10.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round2.2.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.24it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round2.2.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round2.3.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.40it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round2.3.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round2.4.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.79s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round2.4.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round2.5.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.39it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round2.5.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round2.6.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.22s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round2.6.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round2.7.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.04it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round2.7.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round2.8.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round2.8.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round2.9.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.22it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round2.9.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round3.1.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.22it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round3.1.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round3.10.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.11s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round3.10.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round3.2.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.23it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round3.2.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round3.3.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.40it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round3.3.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round3.4.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.82s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round3.4.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round3.5.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.42it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round3.5.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round3.6.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.18s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round3.6.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round3.7.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.05it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round3.7.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round3.8.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.13it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round3.8.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round3.9.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.17it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round3.9.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round4.1.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.14it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round4.1.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round4.10.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.14s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round4.10.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round4.2.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.16it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round4.2.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round4.3.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.33it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round4.3.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round4.4.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.77s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round4.4.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round4.5.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.36it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round4.5.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round4.6.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.27s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round4.6.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round4.7.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round4.7.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round4.8.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.02it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round4.8.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round4.9.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.15it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round4.9.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round5.1.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.18it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round5.1.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round5.10.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.28s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round5.10.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round5.2.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round5.2.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round5.3.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.19it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round5.3.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round5.4.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:04<00:00,  2.26s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round5.4.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round5.5.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.52it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round5.5.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round5.6.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.37s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round5.6.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round5.7.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.02it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round5.7.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round5.8.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.01s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round5.8.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round5.9.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.13it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round5.9.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round6.1.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.14it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round6.1.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round6.10.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.45s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round6.10.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round6.2.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.22it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round6.2.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round6.3.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.04it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round6.3.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round6.4.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:04<00:00,  2.06s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round6.4.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round6.5.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round6.5.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round6.6.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.75s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round6.6.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round6.7.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.13it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round6.7.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round6.8.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.07s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round6.8.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round6.9.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.03it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round6.9.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round1.1.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.03s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round1.1.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round1.10.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round1.10.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round1.2.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.04s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round1.2.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round1.3.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.18it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round1.3.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round1.4.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.09s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round1.4.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round1.5.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.15s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round1.5.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round1.6.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.29s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round1.6.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round1.7.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.40it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round1.7.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round1.8.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.01s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round1.8.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round1.9.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.18s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round1.9.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round2.1.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.15it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round2.1.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round2.10.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.17it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round2.10.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round2.2.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.02it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round2.2.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round2.3.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.25it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round2.3.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round2.4.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.06s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round2.4.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round2.5.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.29s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round2.5.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round2.6.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.44s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round2.6.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round2.7.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.17it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round2.7.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round2.8.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.11s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round2.8.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round2.9.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.22s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round2.9.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round3.1.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.01s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round3.1.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round3.10.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.03it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round3.10.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round3.2.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.06s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round3.2.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round3.3.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.17s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round3.3.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round3.4.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.19s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round3.4.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round3.5.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.30s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round3.5.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round3.6.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.30s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round3.6.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round3.7.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.19it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round3.7.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round3.8.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.11s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round3.8.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round3.9.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.46s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round3.9.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round4.1.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round4.1.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round4.10.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round4.10.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round4.2.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.22s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round4.2.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1980-1984_synthetic_50_round4.3.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# Number of embeddings generated: 50
# ...
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round1.9.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:04<00:00,  2.19s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round1.9.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round2.1.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.64s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round2.1.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round2.10.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.67s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round2.10.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round2.2.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.71s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round2.2.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round2.3.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.74s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round2.3.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round2.4.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:04<00:00,  2.23s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round2.4.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round2.5.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.47s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round2.5.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round2.6.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.64s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round2.6.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round2.7.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.82s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round2.7.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round2.8.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:06<00:00,  3.21s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round2.8.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round2.9.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:04<00:00,  2.12s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round2.9.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round3.1.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.69s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round3.1.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round3.10.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.78s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round3.10.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round3.2.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.75s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round3.2.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round3.3.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.72s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round3.3.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round3.4.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:04<00:00,  2.26s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round3.4.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round3.5.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.53s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round3.5.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round3.6.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.63s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round3.6.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round3.7.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.75s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round3.7.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round3.8.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:06<00:00,  3.05s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round3.8.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round3.9.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:04<00:00,  2.25s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round3.9.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round4.1.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.73s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round4.1.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round4.10.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.88s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round4.10.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round4.2.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.72s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round4.2.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round4.3.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.82s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round4.3.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round4.4.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:04<00:00,  2.22s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round4.4.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round4.5.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.64s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round4.5.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round4.6.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.72s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round4.6.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round4.7.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.73s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round4.7.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round4.8.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:06<00:00,  3.05s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round4.8.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round4.9.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:04<00:00,  2.30s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round4.9.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round5.1.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.78s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round5.1.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round5.10.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.83s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round5.10.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round5.2.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.81s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round5.2.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round5.3.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.70s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round5.3.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round5.4.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:05<00:00,  2.51s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round5.4.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round5.5.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.59s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round5.5.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round5.6.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.75s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round5.6.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round5.7.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.76s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round5.7.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round5.8.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:06<00:00,  3.11s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round5.8.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round5.9.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:04<00:00,  2.15s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round5.9.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round6.1.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.72s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round6.1.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round6.10.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.83s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round6.10.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round6.2.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.74s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round6.2.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round6.3.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.74s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round6.3.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round6.4.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:05<00:00,  2.51s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round6.4.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round6.5.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.56s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round6.5.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round6.6.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.70s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round6.6.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round6.7.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.83s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round6.7.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round6.8.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:06<00:00,  3.08s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round6.8.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round6.9.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:04<00:00,  2.17s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\trauma_2015-2019_synthetic_50_round6.9.tsv_cds_mpnet
# Skipping file: warnings.log (no matching target found)
# Processing completed.

# %%
# %run step7.4_control_combined.5-year.cosine.mpnet.py
# Out:
# Processed file: abuse_1970-1974_synthetic_50_round1.1.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 1 | Repeat: 1
# Processed file: abuse_1970-1974_synthetic_50_round1.10.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 1 | Repeat: 10
# Processed file: abuse_1970-1974_synthetic_50_round1.2.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 1 | Repeat: 2
# Processed file: abuse_1970-1974_synthetic_50_round1.3.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 1 | Repeat: 3
# Processed file: abuse_1970-1974_synthetic_50_round1.4.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 1 | Repeat: 4
# Processed file: abuse_1970-1974_synthetic_50_round1.5.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 1 | Repeat: 5
# Processed file: abuse_1970-1974_synthetic_50_round1.6.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 1 | Repeat: 6
# Processed file: abuse_1970-1974_synthetic_50_round1.7.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 1 | Repeat: 7
# Processed file: abuse_1970-1974_synthetic_50_round1.8.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 1 | Repeat: 8
# Processed file: abuse_1970-1974_synthetic_50_round1.9.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 1 | Repeat: 9
# Processed file: abuse_1970-1974_synthetic_50_round2.1.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 2 | Repeat: 1
# Processed file: abuse_1970-1974_synthetic_50_round2.10.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 2 | Repeat: 10
# Processed file: abuse_1970-1974_synthetic_50_round2.2.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 2 | Repeat: 2
# Processed file: abuse_1970-1974_synthetic_50_round2.3.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 2 | Repeat: 3
# Processed file: abuse_1970-1974_synthetic_50_round2.4.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 2 | Repeat: 4
# Processed file: abuse_1970-1974_synthetic_50_round2.5.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 2 | Repeat: 5
# Processed file: abuse_1970-1974_synthetic_50_round2.6.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 2 | Repeat: 6
# Processed file: abuse_1970-1974_synthetic_50_round2.7.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 2 | Repeat: 7
# Processed file: abuse_1970-1974_synthetic_50_round2.8.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 2 | Repeat: 8
# Processed file: abuse_1970-1974_synthetic_50_round2.9.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 2 | Repeat: 9
# Processed file: abuse_1970-1974_synthetic_50_round3.1.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 3 | Repeat: 1
# Processed file: abuse_1970-1974_synthetic_50_round3.10.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 3 | Repeat: 10
# Processed file: abuse_1970-1974_synthetic_50_round3.2.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 3 | Repeat: 2
# Processed file: abuse_1970-1974_synthetic_50_round3.3.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 3 | Repeat: 3
# Processed file: abuse_1970-1974_synthetic_50_round3.4.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 3 | Repeat: 4
# Processed file: abuse_1970-1974_synthetic_50_round3.5.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 3 | Repeat: 5
# Processed file: abuse_1970-1974_synthetic_50_round3.6.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 3 | Repeat: 6
# Processed file: abuse_1970-1974_synthetic_50_round3.7.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 3 | Repeat: 7
# Processed file: abuse_1970-1974_synthetic_50_round3.8.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 3 | Repeat: 8
# Processed file: abuse_1970-1974_synthetic_50_round3.9.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 3 | Repeat: 9
# Processed file: abuse_1970-1974_synthetic_50_round4.1.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 4 | Repeat: 1
# Processed file: abuse_1970-1974_synthetic_50_round4.10.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 4 | Repeat: 10
# Processed file: abuse_1970-1974_synthetic_50_round4.2.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 4 | Repeat: 2
# Processed file: abuse_1970-1974_synthetic_50_round4.3.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 4 | Repeat: 3
# Processed file: abuse_1970-1974_synthetic_50_round4.4.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 4 | Repeat: 4
# Processed file: abuse_1970-1974_synthetic_50_round4.5.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 4 | Repeat: 5
# Processed file: abuse_1970-1974_synthetic_50_round4.6.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 4 | Repeat: 6
# Processed file: abuse_1970-1974_synthetic_50_round4.7.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 4 | Repeat: 7
# Processed file: abuse_1970-1974_synthetic_50_round4.8.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 4 | Repeat: 8
# Processed file: abuse_1970-1974_synthetic_50_round4.9.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 4 | Repeat: 9
# Processed file: abuse_1970-1974_synthetic_50_round5.1.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 5 | Repeat: 1
# Processed file: abuse_1970-1974_synthetic_50_round5.10.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 5 | Repeat: 10
# Processed file: abuse_1970-1974_synthetic_50_round5.2.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 5 | Repeat: 2
# Processed file: abuse_1970-1974_synthetic_50_round5.3.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 5 | Repeat: 3
# Processed file: abuse_1970-1974_synthetic_50_round5.4.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 5 | Repeat: 4
# Processed file: abuse_1970-1974_synthetic_50_round5.5.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 5 | Repeat: 5
# Processed file: abuse_1970-1974_synthetic_50_round5.6.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 5 | Repeat: 6
# Processed file: abuse_1970-1974_synthetic_50_round5.7.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 5 | Repeat: 7
# Processed file: abuse_1970-1974_synthetic_50_round5.8.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 5 | Repeat: 8
# Processed file: abuse_1970-1974_synthetic_50_round5.9.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 5 | Repeat: 9
# Processed file: abuse_1970-1974_synthetic_50_round6.1.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 6 | Repeat: 1
# Processed file: abuse_1970-1974_synthetic_50_round6.10.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 6 | Repeat: 10
# Processed file: abuse_1970-1974_synthetic_50_round6.2.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 6 | Repeat: 2
# Processed file: abuse_1970-1974_synthetic_50_round6.3.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 6 | Repeat: 3
# Processed file: abuse_1970-1974_synthetic_50_round6.4.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 6 | Repeat: 4
# Processed file: abuse_1970-1974_synthetic_50_round6.5.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 6 | Repeat: 5
# Processed file: abuse_1970-1974_synthetic_50_round6.6.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 6 | Repeat: 6
# Processed file: abuse_1970-1974_synthetic_50_round6.7.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 6 | Repeat: 7
# Processed file: abuse_1970-1974_synthetic_50_round6.8.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 6 | Repeat: 8
# Processed file: abuse_1970-1974_synthetic_50_round6.9.tsv_cds_mpnet | Epoch: 1970-1974 | Term: abuse | Round: 6 | Repeat: 9
# Processed file: abuse_1975-1979_synthetic_50_round1.1.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 1 | Repeat: 1
# Processed file: abuse_1975-1979_synthetic_50_round1.10.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 1 | Repeat: 10
# Processed file: abuse_1975-1979_synthetic_50_round1.2.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 1 | Repeat: 2
# Processed file: abuse_1975-1979_synthetic_50_round1.3.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 1 | Repeat: 3
# Processed file: abuse_1975-1979_synthetic_50_round1.4.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 1 | Repeat: 4
# Processed file: abuse_1975-1979_synthetic_50_round1.5.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 1 | Repeat: 5
# Processed file: abuse_1975-1979_synthetic_50_round1.6.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 1 | Repeat: 6
# Processed file: abuse_1975-1979_synthetic_50_round1.7.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 1 | Repeat: 7
# Processed file: abuse_1975-1979_synthetic_50_round1.8.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 1 | Repeat: 8
# Processed file: abuse_1975-1979_synthetic_50_round1.9.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 1 | Repeat: 9
# Processed file: abuse_1975-1979_synthetic_50_round2.1.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 2 | Repeat: 1
# Processed file: abuse_1975-1979_synthetic_50_round2.10.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 2 | Repeat: 10
# Processed file: abuse_1975-1979_synthetic_50_round2.2.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 2 | Repeat: 2
# Processed file: abuse_1975-1979_synthetic_50_round2.3.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 2 | Repeat: 3
# Processed file: abuse_1975-1979_synthetic_50_round2.4.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 2 | Repeat: 4
# Processed file: abuse_1975-1979_synthetic_50_round2.5.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 2 | Repeat: 5
# Processed file: abuse_1975-1979_synthetic_50_round2.6.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 2 | Repeat: 6
# Processed file: abuse_1975-1979_synthetic_50_round2.7.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 2 | Repeat: 7
# Processed file: abuse_1975-1979_synthetic_50_round2.8.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 2 | Repeat: 8
# Processed file: abuse_1975-1979_synthetic_50_round2.9.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 2 | Repeat: 9
# Processed file: abuse_1975-1979_synthetic_50_round3.1.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 3 | Repeat: 1
# Processed file: abuse_1975-1979_synthetic_50_round3.10.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 3 | Repeat: 10
# Processed file: abuse_1975-1979_synthetic_50_round3.2.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 3 | Repeat: 2
# Processed file: abuse_1975-1979_synthetic_50_round3.3.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 3 | Repeat: 3
# Processed file: abuse_1975-1979_synthetic_50_round3.4.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 3 | Repeat: 4
# Processed file: abuse_1975-1979_synthetic_50_round3.5.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 3 | Repeat: 5
# Processed file: abuse_1975-1979_synthetic_50_round3.6.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 3 | Repeat: 6
# Processed file: abuse_1975-1979_synthetic_50_round3.7.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 3 | Repeat: 7
# Processed file: abuse_1975-1979_synthetic_50_round3.8.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 3 | Repeat: 8
# Processed file: abuse_1975-1979_synthetic_50_round3.9.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 3 | Repeat: 9
# Processed file: abuse_1975-1979_synthetic_50_round4.1.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 4 | Repeat: 1
# Processed file: abuse_1975-1979_synthetic_50_round4.10.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 4 | Repeat: 10
# Processed file: abuse_1975-1979_synthetic_50_round4.2.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 4 | Repeat: 2
# Processed file: abuse_1975-1979_synthetic_50_round4.3.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 4 | Repeat: 3
# Processed file: abuse_1975-1979_synthetic_50_round4.4.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 4 | Repeat: 4
# Processed file: abuse_1975-1979_synthetic_50_round4.5.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 4 | Repeat: 5
# Processed file: abuse_1975-1979_synthetic_50_round4.6.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 4 | Repeat: 6
# Processed file: abuse_1975-1979_synthetic_50_round4.7.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 4 | Repeat: 7
# Processed file: abuse_1975-1979_synthetic_50_round4.8.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 4 | Repeat: 8
# Processed file: abuse_1975-1979_synthetic_50_round4.9.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 4 | Repeat: 9
# Processed file: abuse_1975-1979_synthetic_50_round5.1.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 5 | Repeat: 1
# Processed file: abuse_1975-1979_synthetic_50_round5.10.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 5 | Repeat: 10
# Processed file: abuse_1975-1979_synthetic_50_round5.2.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 5 | Repeat: 2
# Processed file: abuse_1975-1979_synthetic_50_round5.3.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 5 | Repeat: 3
# Processed file: abuse_1975-1979_synthetic_50_round5.4.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 5 | Repeat: 4
# Processed file: abuse_1975-1979_synthetic_50_round5.5.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 5 | Repeat: 5
# Processed file: abuse_1975-1979_synthetic_50_round5.6.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 5 | Repeat: 6
# Processed file: abuse_1975-1979_synthetic_50_round5.7.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 5 | Repeat: 7
# Processed file: abuse_1975-1979_synthetic_50_round5.8.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 5 | Repeat: 8
# Processed file: abuse_1975-1979_synthetic_50_round5.9.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 5 | Repeat: 9
# Processed file: abuse_1975-1979_synthetic_50_round6.1.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 6 | Repeat: 1
# Processed file: abuse_1975-1979_synthetic_50_round6.10.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 6 | Repeat: 10
# Processed file: abuse_1975-1979_synthetic_50_round6.2.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 6 | Repeat: 2
# Processed file: abuse_1975-1979_synthetic_50_round6.3.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 6 | Repeat: 3
# Processed file: abuse_1975-1979_synthetic_50_round6.4.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 6 | Repeat: 4
# Processed file: abuse_1975-1979_synthetic_50_round6.5.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 6 | Repeat: 5
# Processed file: abuse_1975-1979_synthetic_50_round6.6.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 6 | Repeat: 6
# Processed file: abuse_1975-1979_synthetic_50_round6.7.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 6 | Repeat: 7
# Processed file: abuse_1975-1979_synthetic_50_round6.8.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 6 | Repeat: 8
# Processed file: abuse_1975-1979_synthetic_50_round6.9.tsv_cds_mpnet | Epoch: 1975-1979 | Term: abuse | Round: 6 | Repeat: 9
# Processed file: abuse_1980-1984_synthetic_50_round1.1.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 1 | Repeat: 1
# Processed file: abuse_1980-1984_synthetic_50_round1.10.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 1 | Repeat: 10
# Processed file: abuse_1980-1984_synthetic_50_round1.2.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 1 | Repeat: 2
# Processed file: abuse_1980-1984_synthetic_50_round1.3.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 1 | Repeat: 3
# Processed file: abuse_1980-1984_synthetic_50_round1.4.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 1 | Repeat: 4
# Processed file: abuse_1980-1984_synthetic_50_round1.5.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 1 | Repeat: 5
# Processed file: abuse_1980-1984_synthetic_50_round1.6.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 1 | Repeat: 6
# Processed file: abuse_1980-1984_synthetic_50_round1.7.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 1 | Repeat: 7
# Processed file: abuse_1980-1984_synthetic_50_round1.8.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 1 | Repeat: 8
# Processed file: abuse_1980-1984_synthetic_50_round1.9.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 1 | Repeat: 9
# Processed file: abuse_1980-1984_synthetic_50_round2.1.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 2 | Repeat: 1
# Processed file: abuse_1980-1984_synthetic_50_round2.10.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 2 | Repeat: 10
# Processed file: abuse_1980-1984_synthetic_50_round2.2.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 2 | Repeat: 2
# Processed file: abuse_1980-1984_synthetic_50_round2.3.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 2 | Repeat: 3
# Processed file: abuse_1980-1984_synthetic_50_round2.4.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 2 | Repeat: 4
# Processed file: abuse_1980-1984_synthetic_50_round2.5.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 2 | Repeat: 5
# Processed file: abuse_1980-1984_synthetic_50_round2.6.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 2 | Repeat: 6
# Processed file: abuse_1980-1984_synthetic_50_round2.7.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 2 | Repeat: 7
# Processed file: abuse_1980-1984_synthetic_50_round2.8.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 2 | Repeat: 8
# Processed file: abuse_1980-1984_synthetic_50_round2.9.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 2 | Repeat: 9
# Processed file: abuse_1980-1984_synthetic_50_round3.1.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 3 | Repeat: 1
# Processed file: abuse_1980-1984_synthetic_50_round3.10.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 3 | Repeat: 10
# Processed file: abuse_1980-1984_synthetic_50_round3.2.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 3 | Repeat: 2
# Processed file: abuse_1980-1984_synthetic_50_round3.3.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 3 | Repeat: 3
# Processed file: abuse_1980-1984_synthetic_50_round3.4.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 3 | Repeat: 4
# Processed file: abuse_1980-1984_synthetic_50_round3.5.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 3 | Repeat: 5
# Processed file: abuse_1980-1984_synthetic_50_round3.6.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 3 | Repeat: 6
# Processed file: abuse_1980-1984_synthetic_50_round3.7.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 3 | Repeat: 7
# Processed file: abuse_1980-1984_synthetic_50_round3.8.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 3 | Repeat: 8
# Processed file: abuse_1980-1984_synthetic_50_round3.9.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 3 | Repeat: 9
# Processed file: abuse_1980-1984_synthetic_50_round4.1.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 4 | Repeat: 1
# Processed file: abuse_1980-1984_synthetic_50_round4.10.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 4 | Repeat: 10
# Processed file: abuse_1980-1984_synthetic_50_round4.2.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 4 | Repeat: 2
# Processed file: abuse_1980-1984_synthetic_50_round4.3.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 4 | Repeat: 3
# Processed file: abuse_1980-1984_synthetic_50_round4.4.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 4 | Repeat: 4
# Processed file: abuse_1980-1984_synthetic_50_round4.5.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 4 | Repeat: 5
# Processed file: abuse_1980-1984_synthetic_50_round4.6.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 4 | Repeat: 6
# Processed file: abuse_1980-1984_synthetic_50_round4.7.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 4 | Repeat: 7
# Processed file: abuse_1980-1984_synthetic_50_round4.8.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 4 | Repeat: 8
# Processed file: abuse_1980-1984_synthetic_50_round4.9.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 4 | Repeat: 9
# Processed file: abuse_1980-1984_synthetic_50_round5.1.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 5 | Repeat: 1
# Processed file: abuse_1980-1984_synthetic_50_round5.10.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 5 | Repeat: 10
# Processed file: abuse_1980-1984_synthetic_50_round5.2.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 5 | Repeat: 2
# Processed file: abuse_1980-1984_synthetic_50_round5.3.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 5 | Repeat: 3
# Processed file: abuse_1980-1984_synthetic_50_round5.4.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 5 | Repeat: 4
# Processed file: abuse_1980-1984_synthetic_50_round5.5.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 5 | Repeat: 5
# Processed file: abuse_1980-1984_synthetic_50_round5.6.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 5 | Repeat: 6
# Processed file: abuse_1980-1984_synthetic_50_round5.7.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 5 | Repeat: 7
# Processed file: abuse_1980-1984_synthetic_50_round5.8.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 5 | Repeat: 8
# Processed file: abuse_1980-1984_synthetic_50_round5.9.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 5 | Repeat: 9
# Processed file: abuse_1980-1984_synthetic_50_round6.1.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 6 | Repeat: 1
# Processed file: abuse_1980-1984_synthetic_50_round6.10.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 6 | Repeat: 10
# Processed file: abuse_1980-1984_synthetic_50_round6.2.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 6 | Repeat: 2
# Processed file: abuse_1980-1984_synthetic_50_round6.3.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 6 | Repeat: 3
# Processed file: abuse_1980-1984_synthetic_50_round6.4.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 6 | Repeat: 4
# Processed file: abuse_1980-1984_synthetic_50_round6.5.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 6 | Repeat: 5
# Processed file: abuse_1980-1984_synthetic_50_round6.6.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 6 | Repeat: 6
# Processed file: abuse_1980-1984_synthetic_50_round6.7.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 6 | Repeat: 7
# Processed file: abuse_1980-1984_synthetic_50_round6.8.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 6 | Repeat: 8
# Processed file: abuse_1980-1984_synthetic_50_round6.9.tsv_cds_mpnet | Epoch: 1980-1984 | Term: abuse | Round: 6 | Repeat: 9
# Processed file: abuse_1985-1989_synthetic_50_round1.1.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 1 | Repeat: 1
# Processed file: abuse_1985-1989_synthetic_50_round1.10.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 1 | Repeat: 10
# Processed file: abuse_1985-1989_synthetic_50_round1.2.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 1 | Repeat: 2
# Processed file: abuse_1985-1989_synthetic_50_round1.3.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 1 | Repeat: 3
# Processed file: abuse_1985-1989_synthetic_50_round1.4.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 1 | Repeat: 4
# Processed file: abuse_1985-1989_synthetic_50_round1.5.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 1 | Repeat: 5
# Processed file: abuse_1985-1989_synthetic_50_round1.6.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 1 | Repeat: 6
# Processed file: abuse_1985-1989_synthetic_50_round1.7.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 1 | Repeat: 7
# Processed file: abuse_1985-1989_synthetic_50_round1.8.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 1 | Repeat: 8
# Processed file: abuse_1985-1989_synthetic_50_round1.9.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 1 | Repeat: 9
# Processed file: abuse_1985-1989_synthetic_50_round2.1.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 2 | Repeat: 1
# Processed file: abuse_1985-1989_synthetic_50_round2.10.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 2 | Repeat: 10
# Processed file: abuse_1985-1989_synthetic_50_round2.2.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 2 | Repeat: 2
# Processed file: abuse_1985-1989_synthetic_50_round2.3.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 2 | Repeat: 3
# Processed file: abuse_1985-1989_synthetic_50_round2.4.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 2 | Repeat: 4
# Processed file: abuse_1985-1989_synthetic_50_round2.5.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 2 | Repeat: 5
# Processed file: abuse_1985-1989_synthetic_50_round2.6.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 2 | Repeat: 6
# Processed file: abuse_1985-1989_synthetic_50_round2.7.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 2 | Repeat: 7
# Processed file: abuse_1985-1989_synthetic_50_round2.8.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 2 | Repeat: 8
# Processed file: abuse_1985-1989_synthetic_50_round2.9.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 2 | Repeat: 9
# Processed file: abuse_1985-1989_synthetic_50_round3.1.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 3 | Repeat: 1
# Processed file: abuse_1985-1989_synthetic_50_round3.10.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 3 | Repeat: 10
# Processed file: abuse_1985-1989_synthetic_50_round3.2.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 3 | Repeat: 2
# Processed file: abuse_1985-1989_synthetic_50_round3.3.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 3 | Repeat: 3
# Processed file: abuse_1985-1989_synthetic_50_round3.4.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 3 | Repeat: 4
# Processed file: abuse_1985-1989_synthetic_50_round3.5.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 3 | Repeat: 5
# Processed file: abuse_1985-1989_synthetic_50_round3.6.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 3 | Repeat: 6
# Processed file: abuse_1985-1989_synthetic_50_round3.7.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 3 | Repeat: 7
# Processed file: abuse_1985-1989_synthetic_50_round3.8.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 3 | Repeat: 8
# Processed file: abuse_1985-1989_synthetic_50_round3.9.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 3 | Repeat: 9
# Processed file: abuse_1985-1989_synthetic_50_round4.1.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 4 | Repeat: 1
# Processed file: abuse_1985-1989_synthetic_50_round4.10.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 4 | Repeat: 10
# Processed file: abuse_1985-1989_synthetic_50_round4.2.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 4 | Repeat: 2
# Processed file: abuse_1985-1989_synthetic_50_round4.3.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 4 | Repeat: 3
# Processed file: abuse_1985-1989_synthetic_50_round4.4.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 4 | Repeat: 4
# Processed file: abuse_1985-1989_synthetic_50_round4.5.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 4 | Repeat: 5
# Processed file: abuse_1985-1989_synthetic_50_round4.6.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 4 | Repeat: 6
# Processed file: abuse_1985-1989_synthetic_50_round4.7.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 4 | Repeat: 7
# Processed file: abuse_1985-1989_synthetic_50_round4.8.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 4 | Repeat: 8
# Processed file: abuse_1985-1989_synthetic_50_round4.9.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 4 | Repeat: 9
# Processed file: abuse_1985-1989_synthetic_50_round5.1.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 5 | Repeat: 1
# Processed file: abuse_1985-1989_synthetic_50_round5.10.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 5 | Repeat: 10
# Processed file: abuse_1985-1989_synthetic_50_round5.2.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 5 | Repeat: 2
# Processed file: abuse_1985-1989_synthetic_50_round5.3.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 5 | Repeat: 3
# Processed file: abuse_1985-1989_synthetic_50_round5.4.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 5 | Repeat: 4
# Processed file: abuse_1985-1989_synthetic_50_round5.5.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 5 | Repeat: 5
# Processed file: abuse_1985-1989_synthetic_50_round5.6.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 5 | Repeat: 6
# Processed file: abuse_1985-1989_synthetic_50_round5.7.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 5 | Repeat: 7
# Processed file: abuse_1985-1989_synthetic_50_round5.8.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 5 | Repeat: 8
# Processed file: abuse_1985-1989_synthetic_50_round5.9.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 5 | Repeat: 9
# Processed file: abuse_1985-1989_synthetic_50_round6.1.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 6 | Repeat: 1
# Processed file: abuse_1985-1989_synthetic_50_round6.10.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 6 | Repeat: 10
# Processed file: abuse_1985-1989_synthetic_50_round6.2.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 6 | Repeat: 2
# Processed file: abuse_1985-1989_synthetic_50_round6.3.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 6 | Repeat: 3
# Processed file: abuse_1985-1989_synthetic_50_round6.4.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 6 | Repeat: 4
# Processed file: abuse_1985-1989_synthetic_50_round6.5.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 6 | Repeat: 5
# Processed file: abuse_1985-1989_synthetic_50_round6.6.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 6 | Repeat: 6
# Processed file: abuse_1985-1989_synthetic_50_round6.7.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 6 | Repeat: 7
# Processed file: abuse_1985-1989_synthetic_50_round6.8.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 6 | Repeat: 8
# Processed file: abuse_1985-1989_synthetic_50_round6.9.tsv_cds_mpnet | Epoch: 1985-1989 | Term: abuse | Round: 6 | Repeat: 9
# Processed file: abuse_1990-1994_synthetic_50_round1.1.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 1 | Repeat: 1
# Processed file: abuse_1990-1994_synthetic_50_round1.10.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 1 | Repeat: 10
# Processed file: abuse_1990-1994_synthetic_50_round1.2.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 1 | Repeat: 2
# Processed file: abuse_1990-1994_synthetic_50_round1.3.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 1 | Repeat: 3
# Processed file: abuse_1990-1994_synthetic_50_round1.4.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 1 | Repeat: 4
# Processed file: abuse_1990-1994_synthetic_50_round1.5.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 1 | Repeat: 5
# Processed file: abuse_1990-1994_synthetic_50_round1.6.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 1 | Repeat: 6
# Processed file: abuse_1990-1994_synthetic_50_round1.7.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 1 | Repeat: 7
# Processed file: abuse_1990-1994_synthetic_50_round1.8.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 1 | Repeat: 8
# Processed file: abuse_1990-1994_synthetic_50_round1.9.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 1 | Repeat: 9
# Processed file: abuse_1990-1994_synthetic_50_round2.1.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 2 | Repeat: 1
# Processed file: abuse_1990-1994_synthetic_50_round2.10.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 2 | Repeat: 10
# Processed file: abuse_1990-1994_synthetic_50_round2.2.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 2 | Repeat: 2
# Processed file: abuse_1990-1994_synthetic_50_round2.3.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 2 | Repeat: 3
# Processed file: abuse_1990-1994_synthetic_50_round2.4.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 2 | Repeat: 4
# Processed file: abuse_1990-1994_synthetic_50_round2.5.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 2 | Repeat: 5
# Processed file: abuse_1990-1994_synthetic_50_round2.6.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 2 | Repeat: 6
# Processed file: abuse_1990-1994_synthetic_50_round2.7.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 2 | Repeat: 7
# Processed file: abuse_1990-1994_synthetic_50_round2.8.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 2 | Repeat: 8
# Processed file: abuse_1990-1994_synthetic_50_round2.9.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 2 | Repeat: 9
# Processed file: abuse_1990-1994_synthetic_50_round3.1.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 3 | Repeat: 1
# Processed file: abuse_1990-1994_synthetic_50_round3.10.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 3 | Repeat: 10
# Processed file: abuse_1990-1994_synthetic_50_round3.2.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 3 | Repeat: 2
# Processed file: abuse_1990-1994_synthetic_50_round3.3.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 3 | Repeat: 3
# Processed file: abuse_1990-1994_synthetic_50_round3.4.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 3 | Repeat: 4
# Processed file: abuse_1990-1994_synthetic_50_round3.5.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 3 | Repeat: 5
# Processed file: abuse_1990-1994_synthetic_50_round3.6.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 3 | Repeat: 6
# Processed file: abuse_1990-1994_synthetic_50_round3.7.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 3 | Repeat: 7
# Processed file: abuse_1990-1994_synthetic_50_round3.8.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 3 | Repeat: 8
# Processed file: abuse_1990-1994_synthetic_50_round3.9.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 3 | Repeat: 9
# Processed file: abuse_1990-1994_synthetic_50_round4.1.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 4 | Repeat: 1
# Processed file: abuse_1990-1994_synthetic_50_round4.10.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 4 | Repeat: 10
# Processed file: abuse_1990-1994_synthetic_50_round4.2.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 4 | Repeat: 2
# Processed file: abuse_1990-1994_synthetic_50_round4.3.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 4 | Repeat: 3
# Processed file: abuse_1990-1994_synthetic_50_round4.4.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 4 | Repeat: 4
# Processed file: abuse_1990-1994_synthetic_50_round4.5.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 4 | Repeat: 5
# Processed file: abuse_1990-1994_synthetic_50_round4.6.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 4 | Repeat: 6
# Processed file: abuse_1990-1994_synthetic_50_round4.7.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 4 | Repeat: 7
# Processed file: abuse_1990-1994_synthetic_50_round4.8.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 4 | Repeat: 8
# Processed file: abuse_1990-1994_synthetic_50_round4.9.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 4 | Repeat: 9
# Processed file: abuse_1990-1994_synthetic_50_round5.1.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 5 | Repeat: 1
# Processed file: abuse_1990-1994_synthetic_50_round5.10.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 5 | Repeat: 10
# Processed file: abuse_1990-1994_synthetic_50_round5.2.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 5 | Repeat: 2
# Processed file: abuse_1990-1994_synthetic_50_round5.3.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 5 | Repeat: 3
# Processed file: abuse_1990-1994_synthetic_50_round5.4.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 5 | Repeat: 4
# Processed file: abuse_1990-1994_synthetic_50_round5.5.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 5 | Repeat: 5
# Processed file: abuse_1990-1994_synthetic_50_round5.6.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 5 | Repeat: 6
# Processed file: abuse_1990-1994_synthetic_50_round5.7.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 5 | Repeat: 7
# Processed file: abuse_1990-1994_synthetic_50_round5.8.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 5 | Repeat: 8
# Processed file: abuse_1990-1994_synthetic_50_round5.9.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 5 | Repeat: 9
# Processed file: abuse_1990-1994_synthetic_50_round6.1.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 6 | Repeat: 1
# Processed file: abuse_1990-1994_synthetic_50_round6.10.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 6 | Repeat: 10
# Processed file: abuse_1990-1994_synthetic_50_round6.2.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 6 | Repeat: 2
# Processed file: abuse_1990-1994_synthetic_50_round6.3.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 6 | Repeat: 3
# Processed file: abuse_1990-1994_synthetic_50_round6.4.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 6 | Repeat: 4
# Processed file: abuse_1990-1994_synthetic_50_round6.5.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 6 | Repeat: 5
# Processed file: abuse_1990-1994_synthetic_50_round6.6.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 6 | Repeat: 6
# Processed file: abuse_1990-1994_synthetic_50_round6.7.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 6 | Repeat: 7
# Processed file: abuse_1990-1994_synthetic_50_round6.8.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 6 | Repeat: 8
# Processed file: abuse_1990-1994_synthetic_50_round6.9.tsv_cds_mpnet | Epoch: 1990-1994 | Term: abuse | Round: 6 | Repeat: 9
# Processed file: abuse_1995-1999_synthetic_50_round1.1.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 1 | Repeat: 1
# Processed file: abuse_1995-1999_synthetic_50_round1.10.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 1 | Repeat: 10
# Processed file: abuse_1995-1999_synthetic_50_round1.2.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 1 | Repeat: 2
# Processed file: abuse_1995-1999_synthetic_50_round1.3.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 1 | Repeat: 3
# Processed file: abuse_1995-1999_synthetic_50_round1.4.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 1 | Repeat: 4
# Processed file: abuse_1995-1999_synthetic_50_round1.5.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 1 | Repeat: 5
# Processed file: abuse_1995-1999_synthetic_50_round1.6.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 1 | Repeat: 6
# Processed file: abuse_1995-1999_synthetic_50_round1.7.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 1 | Repeat: 7
# Processed file: abuse_1995-1999_synthetic_50_round1.8.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 1 | Repeat: 8
# Processed file: abuse_1995-1999_synthetic_50_round1.9.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 1 | Repeat: 9
# Processed file: abuse_1995-1999_synthetic_50_round2.1.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 2 | Repeat: 1
# Processed file: abuse_1995-1999_synthetic_50_round2.10.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 2 | Repeat: 10
# Processed file: abuse_1995-1999_synthetic_50_round2.2.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 2 | Repeat: 2
# Processed file: abuse_1995-1999_synthetic_50_round2.3.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 2 | Repeat: 3
# Processed file: abuse_1995-1999_synthetic_50_round2.4.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 2 | Repeat: 4
# Processed file: abuse_1995-1999_synthetic_50_round2.5.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 2 | Repeat: 5
# Processed file: abuse_1995-1999_synthetic_50_round2.6.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 2 | Repeat: 6
# Processed file: abuse_1995-1999_synthetic_50_round2.7.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 2 | Repeat: 7
# Processed file: abuse_1995-1999_synthetic_50_round2.8.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 2 | Repeat: 8
# Processed file: abuse_1995-1999_synthetic_50_round2.9.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 2 | Repeat: 9
# Processed file: abuse_1995-1999_synthetic_50_round3.1.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 3 | Repeat: 1
# Processed file: abuse_1995-1999_synthetic_50_round3.10.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 3 | Repeat: 10
# Processed file: abuse_1995-1999_synthetic_50_round3.2.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 3 | Repeat: 2
# Processed file: abuse_1995-1999_synthetic_50_round3.3.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 3 | Repeat: 3
# Processed file: abuse_1995-1999_synthetic_50_round3.4.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 3 | Repeat: 4
# Processed file: abuse_1995-1999_synthetic_50_round3.5.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 3 | Repeat: 5
# Processed file: abuse_1995-1999_synthetic_50_round3.6.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 3 | Repeat: 6
# Processed file: abuse_1995-1999_synthetic_50_round3.7.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 3 | Repeat: 7
# Processed file: abuse_1995-1999_synthetic_50_round3.8.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 3 | Repeat: 8
# Processed file: abuse_1995-1999_synthetic_50_round3.9.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 3 | Repeat: 9
# Processed file: abuse_1995-1999_synthetic_50_round4.1.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 4 | Repeat: 1
# Processed file: abuse_1995-1999_synthetic_50_round4.10.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 4 | Repeat: 10
# Processed file: abuse_1995-1999_synthetic_50_round4.2.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 4 | Repeat: 2
# Processed file: abuse_1995-1999_synthetic_50_round4.3.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 4 | Repeat: 3
# Processed file: abuse_1995-1999_synthetic_50_round4.4.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 4 | Repeat: 4
# Processed file: abuse_1995-1999_synthetic_50_round4.5.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 4 | Repeat: 5
# Processed file: abuse_1995-1999_synthetic_50_round4.6.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 4 | Repeat: 6
# Processed file: abuse_1995-1999_synthetic_50_round4.7.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 4 | Repeat: 7
# Processed file: abuse_1995-1999_synthetic_50_round4.8.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 4 | Repeat: 8
# Processed file: abuse_1995-1999_synthetic_50_round4.9.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 4 | Repeat: 9
# Processed file: abuse_1995-1999_synthetic_50_round5.1.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 5 | Repeat: 1
# Processed file: abuse_1995-1999_synthetic_50_round5.10.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 5 | Repeat: 10
# Processed file: abuse_1995-1999_synthetic_50_round5.2.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 5 | Repeat: 2
# Processed file: abuse_1995-1999_synthetic_50_round5.3.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 5 | Repeat: 3
# Processed file: abuse_1995-1999_synthetic_50_round5.4.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 5 | Repeat: 4
# Processed file: abuse_1995-1999_synthetic_50_round5.5.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 5 | Repeat: 5
# Processed file: abuse_1995-1999_synthetic_50_round5.6.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 5 | Repeat: 6
# Processed file: abuse_1995-1999_synthetic_50_round5.7.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 5 | Repeat: 7
# Processed file: abuse_1995-1999_synthetic_50_round5.8.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 5 | Repeat: 8
# Processed file: abuse_1995-1999_synthetic_50_round5.9.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 5 | Repeat: 9
# Processed file: abuse_1995-1999_synthetic_50_round6.1.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 6 | Repeat: 1
# Processed file: abuse_1995-1999_synthetic_50_round6.10.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 6 | Repeat: 10
# Processed file: abuse_1995-1999_synthetic_50_round6.2.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 6 | Repeat: 2
# Processed file: abuse_1995-1999_synthetic_50_round6.3.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 6 | Repeat: 3
# Processed file: abuse_1995-1999_synthetic_50_round6.4.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 6 | Repeat: 4
# Processed file: abuse_1995-1999_synthetic_50_round6.5.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 6 | Repeat: 5
# Processed file: abuse_1995-1999_synthetic_50_round6.6.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 6 | Repeat: 6
# Processed file: abuse_1995-1999_synthetic_50_round6.7.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 6 | Repeat: 7
# Processed file: abuse_1995-1999_synthetic_50_round6.8.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 6 | Repeat: 8
# Processed file: abuse_1995-1999_synthetic_50_round6.9.tsv_cds_mpnet | Epoch: 1995-1999 | Term: abuse | Round: 6 | Repeat: 9
# Processed file: abuse_2000-2004_synthetic_50_round1.1.tsv_cds_mpnet | Epoch: 2000-2004 | Term: abuse | Round: 1 | Repeat: 1
# Processed file: abuse_2000-2004_synthetic_50_round1.10.tsv_cds_mpnet | Epoch: 2000-2004 | Term: abuse | Round: 1 | Repeat: 10
# Processed file: abuse_2000-2004_synthetic_50_round1.2.tsv_cds_mpnet | Epoch: 2000-2004 | Term: abuse | Round: 1 | Repeat: 2
# Processed file: abuse_2000-2004_synthetic_50_round1.3.tsv_cds_mpnet | Epoch: 2000-2004 | Term: abuse | Round: 1 | Repeat: 3
# Processed file: abuse_2000-2004_synthetic_50_round1.4.tsv_cds_mpnet | Epoch: 2000-2004 | Term: abuse | Round: 1 | Repeat: 4
# Processed file: abuse_2000-2004_synthetic_50_round1.5.tsv_cds_mpnet | Epoch: 2000-2004 | Term: abuse | Round: 1 | Repeat: 5
# Processed file: abuse_2000-2004_synthetic_50_round1.6.tsv_cds_mpnet | Epoch: 2000-2004 | Term: abuse | Round: 1 | Repeat: 6
# Processed file: abuse_2000-2004_synthetic_50_round1.7.tsv_cds_mpnet | Epoch: 2000-2004 | Term: abuse | Round: 1 | Repeat: 7
# Processed file: abuse_2000-2004_synthetic_50_round1.8.tsv_cds_mpnet | Epoch: 2000-2004 | Term: abuse | Round: 1 | Repeat: 8
# Processed file: abuse_2000-2004_synthetic_50_round1.9.tsv_cds_mpnet | Epoch: 2000-2004 | Term: abuse | Round: 1 | Repeat: 9
# Processed file: abuse_2000-2004_synthetic_50_round2.1.tsv_cds_mpnet | Epoch: 2000-2004 | Term: abuse | Round: 2 | Repeat: 1
# Processed file: abuse_2000-2004_synthetic_50_round2.10.tsv_cds_mpnet | Epoch: 2000-2004 | Term: abuse | Round: 2 | Repeat: 10
# Processed file: abuse_2000-2004_synthetic_50_round2.2.tsv_cds_mpnet | Epoch: 2000-2004 | Term: abuse | Round: 2 | Repeat: 2
# Processed file: abuse_2000-2004_synthetic_50_round2.3.tsv_cds_mpnet | Epoch: 2000-2004 | Term: abuse | Round: 2 | Repeat: 3
# Processed file: abuse_2000-2004_synthetic_50_round2.4.tsv_cds_mpnet | Epoch: 2000-2004 | Term: abuse | Round: 2 | Repeat: 4
# Processed file: abuse_2000-2004_synthetic_50_round2.5.tsv_cds_mpnet | Epoch: 2000-2004 | Term: abuse | Round: 2 | Repeat: 5
# Processed file: abuse_2000-2004_synthetic_50_round2.6.tsv_cds_mpnet | Epoch: 2000-2004 | Term: abuse | Round: 2 | Repeat: 6
# Processed file: abuse_2000-2004_synthetic_50_round2.7.tsv_cds_mpnet | Epoch: 2000-2004 | Term: abuse | Round: 2 | Repeat: 7
# Processed file: abuse_2000-2004_synthetic_50_round2.8.tsv_cds_mpnet | Epoch: 2000-2004 | Term: abuse | Round: 2 | Repeat: 8
# Processed file: abuse_2000-2004_synthetic_50_round2.9.tsv_cds_mpnet | Epoch: 2000-2004 | Term: abuse | Round: 2 | Repeat: 9
# Processed file: abuse_2000-2004_synthetic_50_round3.1.tsv_cds_mpnet | Epoch: 2000-2004 | Term: abuse | Round: 3 | Repeat: 1
# Processed file: abuse_2000-2004_synthetic_50_round3.10.tsv_cds_mpnet | Epoch: 2000-2004 | Term: abuse | Round: 3 | Repeat: 10
# Processed file: abuse_2000-2004_synthetic_50_round3.2.tsv_cds_mpnet | Epoch: 2000-2004 | Term: abuse | Round: 3 | Repeat: 2
# Processed file: abuse_2000-2004_synthetic_50_round3.3.tsv_cds_mpnet | Epoch: 2000-2004 | Term: abuse | Round: 3 | Repeat: 3
# Processed file: abuse_2000-2004_synthetic_50_round3.4.tsv_cds_mpnet | Epoch: 2000-2004 | Term: abuse | Round: 3 | Repeat: 4
# Processed file: abuse_2000-2004_synthetic_50_round3.5.tsv_cds_mpnet | Epoch: 2000-2004 | Term: abuse | Round: 3 | Repeat: 5
# ...
# Processed file: trauma_2005-2009_synthetic_50_round6.5.tsv_cds_mpnet | Epoch: 2005-2009 | Term: trauma | Round: 6 | Repeat: 5
# Processed file: trauma_2005-2009_synthetic_50_round6.6.tsv_cds_mpnet | Epoch: 2005-2009 | Term: trauma | Round: 6 | Repeat: 6
# Processed file: trauma_2005-2009_synthetic_50_round6.7.tsv_cds_mpnet | Epoch: 2005-2009 | Term: trauma | Round: 6 | Repeat: 7
# Processed file: trauma_2005-2009_synthetic_50_round6.8.tsv_cds_mpnet | Epoch: 2005-2009 | Term: trauma | Round: 6 | Repeat: 8
# Processed file: trauma_2005-2009_synthetic_50_round6.9.tsv_cds_mpnet | Epoch: 2005-2009 | Term: trauma | Round: 6 | Repeat: 9
# Processed file: trauma_2010-2014_synthetic_50_round1.1.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 1 | Repeat: 1
# Processed file: trauma_2010-2014_synthetic_50_round1.10.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 1 | Repeat: 10
# Processed file: trauma_2010-2014_synthetic_50_round1.2.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 1 | Repeat: 2
# Processed file: trauma_2010-2014_synthetic_50_round1.3.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 1 | Repeat: 3
# Processed file: trauma_2010-2014_synthetic_50_round1.4.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 1 | Repeat: 4
# Processed file: trauma_2010-2014_synthetic_50_round1.5.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 1 | Repeat: 5
# Processed file: trauma_2010-2014_synthetic_50_round1.6.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 1 | Repeat: 6
# Processed file: trauma_2010-2014_synthetic_50_round1.7.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 1 | Repeat: 7
# Processed file: trauma_2010-2014_synthetic_50_round1.8.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 1 | Repeat: 8
# Processed file: trauma_2010-2014_synthetic_50_round1.9.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 1 | Repeat: 9
# Processed file: trauma_2010-2014_synthetic_50_round2.1.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 2 | Repeat: 1
# Processed file: trauma_2010-2014_synthetic_50_round2.10.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 2 | Repeat: 10
# Processed file: trauma_2010-2014_synthetic_50_round2.2.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 2 | Repeat: 2
# Processed file: trauma_2010-2014_synthetic_50_round2.3.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 2 | Repeat: 3
# Processed file: trauma_2010-2014_synthetic_50_round2.4.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 2 | Repeat: 4
# Processed file: trauma_2010-2014_synthetic_50_round2.5.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 2 | Repeat: 5
# Processed file: trauma_2010-2014_synthetic_50_round2.6.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 2 | Repeat: 6
# Processed file: trauma_2010-2014_synthetic_50_round2.7.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 2 | Repeat: 7
# Processed file: trauma_2010-2014_synthetic_50_round2.8.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 2 | Repeat: 8
# Processed file: trauma_2010-2014_synthetic_50_round2.9.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 2 | Repeat: 9
# Processed file: trauma_2010-2014_synthetic_50_round3.1.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 3 | Repeat: 1
# Processed file: trauma_2010-2014_synthetic_50_round3.10.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 3 | Repeat: 10
# Processed file: trauma_2010-2014_synthetic_50_round3.2.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 3 | Repeat: 2
# Processed file: trauma_2010-2014_synthetic_50_round3.3.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 3 | Repeat: 3
# Processed file: trauma_2010-2014_synthetic_50_round3.4.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 3 | Repeat: 4
# Processed file: trauma_2010-2014_synthetic_50_round3.5.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 3 | Repeat: 5
# Processed file: trauma_2010-2014_synthetic_50_round3.6.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 3 | Repeat: 6
# Processed file: trauma_2010-2014_synthetic_50_round3.7.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 3 | Repeat: 7
# Processed file: trauma_2010-2014_synthetic_50_round3.8.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 3 | Repeat: 8
# Processed file: trauma_2010-2014_synthetic_50_round3.9.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 3 | Repeat: 9
# Processed file: trauma_2010-2014_synthetic_50_round4.1.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 4 | Repeat: 1
# Processed file: trauma_2010-2014_synthetic_50_round4.10.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 4 | Repeat: 10
# Processed file: trauma_2010-2014_synthetic_50_round4.2.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 4 | Repeat: 2
# Processed file: trauma_2010-2014_synthetic_50_round4.3.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 4 | Repeat: 3
# Processed file: trauma_2010-2014_synthetic_50_round4.4.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 4 | Repeat: 4
# Processed file: trauma_2010-2014_synthetic_50_round4.5.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 4 | Repeat: 5
# Processed file: trauma_2010-2014_synthetic_50_round4.6.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 4 | Repeat: 6
# Processed file: trauma_2010-2014_synthetic_50_round4.7.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 4 | Repeat: 7
# Processed file: trauma_2010-2014_synthetic_50_round4.8.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 4 | Repeat: 8
# Processed file: trauma_2010-2014_synthetic_50_round4.9.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 4 | Repeat: 9
# Processed file: trauma_2010-2014_synthetic_50_round5.1.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 5 | Repeat: 1
# Processed file: trauma_2010-2014_synthetic_50_round5.10.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 5 | Repeat: 10
# Processed file: trauma_2010-2014_synthetic_50_round5.2.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 5 | Repeat: 2
# Processed file: trauma_2010-2014_synthetic_50_round5.3.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 5 | Repeat: 3
# Processed file: trauma_2010-2014_synthetic_50_round5.4.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 5 | Repeat: 4
# Processed file: trauma_2010-2014_synthetic_50_round5.5.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 5 | Repeat: 5
# Processed file: trauma_2010-2014_synthetic_50_round5.6.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 5 | Repeat: 6
# Processed file: trauma_2010-2014_synthetic_50_round5.7.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 5 | Repeat: 7
# Processed file: trauma_2010-2014_synthetic_50_round5.8.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 5 | Repeat: 8
# Processed file: trauma_2010-2014_synthetic_50_round5.9.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 5 | Repeat: 9
# Processed file: trauma_2010-2014_synthetic_50_round6.1.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 6 | Repeat: 1
# Processed file: trauma_2010-2014_synthetic_50_round6.10.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 6 | Repeat: 10
# Processed file: trauma_2010-2014_synthetic_50_round6.2.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 6 | Repeat: 2
# Processed file: trauma_2010-2014_synthetic_50_round6.3.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 6 | Repeat: 3
# Processed file: trauma_2010-2014_synthetic_50_round6.4.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 6 | Repeat: 4
# Processed file: trauma_2010-2014_synthetic_50_round6.5.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 6 | Repeat: 5
# Processed file: trauma_2010-2014_synthetic_50_round6.6.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 6 | Repeat: 6
# Processed file: trauma_2010-2014_synthetic_50_round6.7.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 6 | Repeat: 7
# Processed file: trauma_2010-2014_synthetic_50_round6.8.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 6 | Repeat: 8
# Processed file: trauma_2010-2014_synthetic_50_round6.9.tsv_cds_mpnet | Epoch: 2010-2014 | Term: trauma | Round: 6 | Repeat: 9
# Processed file: trauma_2015-2019_synthetic_50_round1.1.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 1 | Repeat: 1
# Processed file: trauma_2015-2019_synthetic_50_round1.10.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 1 | Repeat: 10
# Processed file: trauma_2015-2019_synthetic_50_round1.2.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 1 | Repeat: 2
# Processed file: trauma_2015-2019_synthetic_50_round1.3.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 1 | Repeat: 3
# Processed file: trauma_2015-2019_synthetic_50_round1.4.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 1 | Repeat: 4
# Processed file: trauma_2015-2019_synthetic_50_round1.5.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 1 | Repeat: 5
# Processed file: trauma_2015-2019_synthetic_50_round1.6.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 1 | Repeat: 6
# Processed file: trauma_2015-2019_synthetic_50_round1.7.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 1 | Repeat: 7
# Processed file: trauma_2015-2019_synthetic_50_round1.8.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 1 | Repeat: 8
# Processed file: trauma_2015-2019_synthetic_50_round1.9.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 1 | Repeat: 9
# Processed file: trauma_2015-2019_synthetic_50_round2.1.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 2 | Repeat: 1
# Processed file: trauma_2015-2019_synthetic_50_round2.10.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 2 | Repeat: 10
# Processed file: trauma_2015-2019_synthetic_50_round2.2.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 2 | Repeat: 2
# Processed file: trauma_2015-2019_synthetic_50_round2.3.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 2 | Repeat: 3
# Processed file: trauma_2015-2019_synthetic_50_round2.4.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 2 | Repeat: 4
# Processed file: trauma_2015-2019_synthetic_50_round2.5.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 2 | Repeat: 5
# Processed file: trauma_2015-2019_synthetic_50_round2.6.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 2 | Repeat: 6
# Processed file: trauma_2015-2019_synthetic_50_round2.7.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 2 | Repeat: 7
# Processed file: trauma_2015-2019_synthetic_50_round2.8.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 2 | Repeat: 8
# Processed file: trauma_2015-2019_synthetic_50_round2.9.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 2 | Repeat: 9
# Processed file: trauma_2015-2019_synthetic_50_round3.1.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 3 | Repeat: 1
# Processed file: trauma_2015-2019_synthetic_50_round3.10.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 3 | Repeat: 10
# Processed file: trauma_2015-2019_synthetic_50_round3.2.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 3 | Repeat: 2
# Processed file: trauma_2015-2019_synthetic_50_round3.3.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 3 | Repeat: 3
# Processed file: trauma_2015-2019_synthetic_50_round3.4.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 3 | Repeat: 4
# Processed file: trauma_2015-2019_synthetic_50_round3.5.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 3 | Repeat: 5
# Processed file: trauma_2015-2019_synthetic_50_round3.6.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 3 | Repeat: 6
# Processed file: trauma_2015-2019_synthetic_50_round3.7.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 3 | Repeat: 7
# Processed file: trauma_2015-2019_synthetic_50_round3.8.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 3 | Repeat: 8
# Processed file: trauma_2015-2019_synthetic_50_round3.9.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 3 | Repeat: 9
# Processed file: trauma_2015-2019_synthetic_50_round4.1.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 4 | Repeat: 1
# Processed file: trauma_2015-2019_synthetic_50_round4.10.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 4 | Repeat: 10
# Processed file: trauma_2015-2019_synthetic_50_round4.2.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 4 | Repeat: 2
# Processed file: trauma_2015-2019_synthetic_50_round4.3.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 4 | Repeat: 3
# Processed file: trauma_2015-2019_synthetic_50_round4.4.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 4 | Repeat: 4
# Processed file: trauma_2015-2019_synthetic_50_round4.5.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 4 | Repeat: 5
# Processed file: trauma_2015-2019_synthetic_50_round4.6.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 4 | Repeat: 6
# Processed file: trauma_2015-2019_synthetic_50_round4.7.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 4 | Repeat: 7
# Processed file: trauma_2015-2019_synthetic_50_round4.8.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 4 | Repeat: 8
# Processed file: trauma_2015-2019_synthetic_50_round4.9.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 4 | Repeat: 9
# Processed file: trauma_2015-2019_synthetic_50_round5.1.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 5 | Repeat: 1
# Processed file: trauma_2015-2019_synthetic_50_round5.10.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 5 | Repeat: 10
# Processed file: trauma_2015-2019_synthetic_50_round5.2.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 5 | Repeat: 2
# Processed file: trauma_2015-2019_synthetic_50_round5.3.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 5 | Repeat: 3
# Processed file: trauma_2015-2019_synthetic_50_round5.4.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 5 | Repeat: 4
# Processed file: trauma_2015-2019_synthetic_50_round5.5.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 5 | Repeat: 5
# Processed file: trauma_2015-2019_synthetic_50_round5.6.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 5 | Repeat: 6
# Processed file: trauma_2015-2019_synthetic_50_round5.7.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 5 | Repeat: 7
# Processed file: trauma_2015-2019_synthetic_50_round5.8.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 5 | Repeat: 8
# Processed file: trauma_2015-2019_synthetic_50_round5.9.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 5 | Repeat: 9
# Processed file: trauma_2015-2019_synthetic_50_round6.1.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 6 | Repeat: 1
# Processed file: trauma_2015-2019_synthetic_50_round6.10.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 6 | Repeat: 10
# Processed file: trauma_2015-2019_synthetic_50_round6.2.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 6 | Repeat: 2
# Processed file: trauma_2015-2019_synthetic_50_round6.3.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 6 | Repeat: 3
# Processed file: trauma_2015-2019_synthetic_50_round6.4.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 6 | Repeat: 4
# Processed file: trauma_2015-2019_synthetic_50_round6.5.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 6 | Repeat: 5
# Processed file: trauma_2015-2019_synthetic_50_round6.6.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 6 | Repeat: 6
# Processed file: trauma_2015-2019_synthetic_50_round6.7.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 6 | Repeat: 7
# Processed file: trauma_2015-2019_synthetic_50_round6.8.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 6 | Repeat: 8
# Processed file: trauma_2015-2019_synthetic_50_round6.9.tsv_cds_mpnet | Epoch: 2015-2019 | Term: trauma | Round: 6 | Repeat: 9
# Saved final combined results to: output/control_final_combined.5-year.cds_mpnet.csv
# Processing completed.

# %%
# %run step7.5_plot_5-year_breadth-index_control.py
# Out:
# Successfully read data from CSV file.

# %% [markdown]
# ## all-year bootstrap sampling strategy

# %%
# Get sentences from all-year samples and put in one files grouped by condition, target
# %run step7.1_control_shuffle_all-year.py
# Out:
# Files have been successfully grouped, split by natural and synthetic, and saved.

# %%
# The script generates randomized uniform samples of natural and synthetic sentences for specified targets, time intervals, and conditions, saving the results into separate 
# files without column headers and differentiating injection ratio rounds in the file names for later aggregation.
# %run step7.2_control_randomly_sample_sentences_all-year.py
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# Loaded corpus from output/all-year/control\input\high\natural\depression_all-year_intensity_natural.tsv, first 5 rows:
#                                             sentence    label
# 0  The fatigue dimension of the MQ remained highl...  natural
# 1  Depression and hopelessness predict myocardial...  natural
# 2  The immunological role of hardiness was ascert...  natural
# 3  Other risk factors were co-morbidity, prehisto...  natural
# 4  A total of 37 patients with remitted geriatric...  natural
# Loaded corpus from output/all-year/control\input\high\natural\anxiety_all-year_intensity_natural.tsv, first 5 rows:
#                                             sentence    label
# 0  After assessing social anxiety and depressive ...  natural
# 1  As a whole, our findings identify task coping ...  natural
# 2  Anxiety symptoms and disorders are common amon...  natural
# 3  Second, the contribution of biological pathway...  natural
# 4  Forty students completed revised Attention Net...  natural
# Loaded corpus from output/all-year/control\input\high\natural\mental_illness_all-year_intensity_natural.tsv, first 5 rows:
#                                             sentence    label
# 0  Homosexuality was regarded as a mental_illness...  natural
# 1  Research literature from positive psychology s...  natural
# 2  A cross-sectional study with 213 people with m...  natural
# 3  These data confirm the generally held view of ...  natural
# 4  In this study of 143 offenders with mental_ill...  natural
# Loaded corpus from output/all-year/control\input\high\natural\trauma_all-year_intensity_natural.tsv, first 5 rows:
#                                             sentence    label
# 0  Specifically, the relationship between a histo...  natural
# 1  In the current article, we utilize betrayal tr...  natural
# 2  The study found that organization of the foste...  natural
# 3  TI-MBSR appears to be a promising and feasible...  natural
# 4  Fifteen of the youth with exposure to trauma w...  natural
# Loaded corpus from output/all-year/control\input\high\natural\abuse_all-year_intensity_natural.tsv, first 5 rows:
#                                             sentence    label
# 0              The median age of abuse was 14 years.  natural
# 1  Native American youth experience higher rates ...  natural
# 2  Parental expectations about how sexual abuse w...  natural
# 3  The results suggests that highly-specialized i...  natural
# 4  Consequently, physical intrusiveness appears t...  natural
# Loaded corpus from output/all-year/control\input\high\natural\mental_health_all-year_intensity_natural.tsv, first 5 rows:
#                                             sentence    label
# 0  Interest in the mental_health of women deploye...  natural
# 1  Policy makers must address Troublesrelated men...  natural
# 2  We did not find a significant relationship bet...  natural
# 3  This article extends our understanding by synt...  natural
# 4  This will improve not only mental_health, but ...  natural
# Loaded corpus from output/all-year/control\input\high\synthetic\depression_all-year_intensity_synthetic.tsv, first 5 rows:
#                                             sentence                label
# 0  A significant, positive relationship was found...  synthetic_intensity
# 1  Children whose fathers had been absent 1 or mo...  synthetic_intensity
# 2  Whether intense somatosensory amplification is...  synthetic_intensity
# 3  The MH subjects were found to use less effecti...  synthetic_intensity
# 4  Of particular importance for psychopharmacolog...  synthetic_intensity
# Loaded corpus from output/all-year/control\input\high\synthetic\mental_illness_all-year_intensity_synthetic.tsv, first 5 rows:
#                                             sentence                label
# 0  Path analyses were used to examine the direct ...  synthetic_intensity
# 1  This urgent mixed-methods study of 300 consume...  synthetic_intensity
# 2  Two intensive clinical pathway interventions -...  synthetic_intensity
# 3  The authors adapted it for use with individual...  synthetic_intensity
# 4  This article describes recent, alarming resear...  synthetic_intensity
# Loaded corpus from output/all-year/control\input\high\synthetic\anxiety_all-year_intensity_synthetic.tsv, first 5 rows:
#                                             sentence                label
# 0  Correlations indicated scores on Direction sub...  synthetic_intensity
# 1  Both quality of life index scores were severel...  synthetic_intensity
# 2  The current review provides a comprehensive ac...  synthetic_intensity
# 3  A possible association between MRI cortisol an...  synthetic_intensity
# 4  We delve deeply into these findings in relatio...  synthetic_intensity
# Loaded corpus from output/all-year/control\input\high\synthetic\abuse_all-year_intensity_synthetic.tsv, first 5 rows:
#                                             sentence                label
# 0  A systematic literature review of the effectiv...  synthetic_intensity
# 1  The Child Sexual Abuse Accommodation Syndrome ...  synthetic_intensity
# 2  This study explored the disturbing social cont...  synthetic_intensity
# 3  The pattern of anal signs varied with the age ...  synthetic_intensity
# 4  Although all women reported a slight decrease ...  synthetic_intensity
# Loaded corpus from output/all-year/control\input\high\synthetic\trauma_all-year_intensity_synthetic.tsv, first 5 rows:
#                                             sentence                label
# 0  These results suggest a powerful link among se...  synthetic_intensity
# 1  The complex and distressing symptom profiles o...  synthetic_intensity
# 2  Understanding the excruciating trauma experien...  synthetic_intensity
# 3  We measured intense symptoms of posttraumatic ...  synthetic_intensity
# 4  A model is proposed of the evolution of overwh...  synthetic_intensity
# Loaded corpus from output/all-year/control\input\high\synthetic\mental_health_all-year_intensity_synthetic.tsv, first 5 rows:
#                                             sentence                label
# 0  The present study is groundbreaking in examini...  synthetic_intensity
# 1  In this study, seven distressed patients betwe...  synthetic_intensity
# 2  Empirical research on critical mental_health c...  synthetic_intensity
# 3  Maternal complete refusal of critical psychiat...  synthetic_intensity
# 4  A classic portrait of the devastated widower, ...  synthetic_intensity
# Loaded corpus from output/all-year/control\input\low\natural\depression_all-year_intensity_natural.tsv, first 5 rows:
#                                             sentence    label
# 0  The fatigue dimension of the MQ remained highl...  natural
# 1  Depression and hopelessness predict myocardial...  natural
# 2  The immunological role of hardiness was ascert...  natural
# 3  Other risk factors were co-morbidity, prehisto...  natural
# 4  A total of 37 patients with remitted geriatric...  natural
# Loaded corpus from output/all-year/control\input\low\natural\mental_illness_all-year_intensity_natural.tsv, first 5 rows:
#                                             sentence    label
# 0  Homosexuality was regarded as a mental_illness...  natural
# 1  Research literature from positive psychology s...  natural
# 2  A cross-sectional study with 213 people with m...  natural
# 3  These data confirm the generally held view of ...  natural
# 4  In this study of 143 offenders with mental_ill...  natural
# Loaded corpus from output/all-year/control\input\low\natural\abuse_all-year_intensity_natural.tsv, first 5 rows:
#                                             sentence    label
# 0              The median age of abuse was 14 years.  natural
# 1  Native American youth experience higher rates ...  natural
# 2  Parental expectations about how sexual abuse w...  natural
# 3  The results suggests that highly-specialized i...  natural
# 4  Consequently, physical intrusiveness appears t...  natural
# Loaded corpus from output/all-year/control\input\low\natural\trauma_all-year_intensity_natural.tsv, first 5 rows:
#                                             sentence    label
# 0  Specifically, the relationship between a histo...  natural
# 1  In the current article, we utilize betrayal tr...  natural
# 2  The study found that organization of the foste...  natural
# 3  TI-MBSR appears to be a promising and feasible...  natural
# 4  Fifteen of the youth with exposure to trauma w...  natural
# Loaded corpus from output/all-year/control\input\low\synthetic\mental_illness_all-year_intensity_synthetic.tsv, first 5 rows:
#                                             sentence                label
# 0  Statistical adjustment for mild mental_illness...  synthetic_intensity
# 1  We identified a noticeable prevalence of menta...  synthetic_intensity
# 2  One hundred patients with moderate mental_illn...  synthetic_intensity
# 3  A noticeable proportion of people who have a m...  synthetic_intensity
# 4  Decreasing the burden of mental_illness will a...  synthetic_intensity
# Loaded corpus from output/all-year/control\input\low\synthetic\depression_all-year_intensity_synthetic.tsv, first 5 rows:
#                                             sentence                label
# 0  The main outcome measures were the self-report...  synthetic_intensity
# 1  Participants also completed the Glasgow Mild D...  synthetic_intensity
# 2  The current study challenges past work showing...  synthetic_intensity
# 3  It is demonstrated that manifestations of 'vit...  synthetic_intensity
# 4  Despite a proliferation of recent research exa...  synthetic_intensity
# Loaded corpus from output/all-year/control\input\low\synthetic\abuse_all-year_intensity_synthetic.tsv, first 5 rows:
#                                             sentence                label
# 0  The aim of this study was to determine the ext...  synthetic_intensity
# 1  This study examined the alcohol and psychiatri...  synthetic_intensity
# 2  This study explored possible associations betw...  synthetic_intensity
# 3  The present investigation was designed to mani...  synthetic_intensity
# 4  As a group, they do not tend to be risk-takers...  synthetic_intensity
# Loaded corpus from output/all-year/control\input\low\natural\anxiety_all-year_intensity_natural.tsv, first 5 rows:
#                                             sentence    label
# 0  After assessing social anxiety and depressive ...  natural
# 1  As a whole, our findings identify task coping ...  natural
# 2  Anxiety symptoms and disorders are common amon...  natural
# 3  Second, the contribution of biological pathway...  natural
# 4  Forty students completed revised Attention Net...  natural
# Loaded corpus from output/all-year/control\input\low\synthetic\trauma_all-year_intensity_synthetic.tsv, first 5 rows:
#                                             sentence                label
# 0  Patterns of mild trauma exposure and symptoms ...  synthetic_intensity
# 1  The neurological competency of maltreated chil...  synthetic_intensity
# 2  Surprisingly, no associations were detected be...  synthetic_intensity
# 3  Consistent with previous work, these results s...  synthetic_intensity
# 4  The current study evaluated whether experience...  synthetic_intensity
# Loaded corpus from output/all-year/control\input\low\synthetic\anxiety_all-year_intensity_synthetic.tsv, first 5 rows:
#                                             sentence                label
# 0  Measures of mild state anxiety and perceived c...  synthetic_intensity
# 1  Subjects in the CSM group reported significant...  synthetic_intensity
# 2  The inbred Roman High- (RHA-I) and Roman Low-A...  synthetic_intensity
# 3  This study briefly examined mild worry in elem...  synthetic_intensity
# 4  Therefore, mild situational interest, task-rel...  synthetic_intensity
# Loaded corpus from output/all-year/control\input\low\natural\mental_health_all-year_intensity_natural.tsv, first 5 rows:
#                                             sentence    label
# 0  Interest in the mental_health of women deploye...  natural
# 1  Policy makers must address Troublesrelated men...  natural
# 2  We did not find a significant relationship bet...  natural
# 3  This article extends our understanding by synt...  natural
# 4  This will improve not only mental_health, but ...  natural
# Loaded corpus from output/all-year/control\input\low\synthetic\mental_health_all-year_intensity_synthetic.tsv, first 5 rows:
#                                             sentence                label
# 0  The study demonstrated some variability in rou...  synthetic_intensity
# 1  However, most of them are presented without co...  synthetic_intensity
# 2  We outline the basic techniques used by a trai...  synthetic_intensity
# 3  The current study sought to quantify the cogni...  synthetic_intensity
# 4  Our findings suggest that mild mood repair is ...  synthetic_intensity
# 100%|██████████| 6/6 [00:05<00:00,  1.16it/s]

# %%
# %run step7.3_control_process_sentences_all-year.cosine_mpnet.py
# Out:
# c:\Users\naomi\anaconda3\Lib\site-packages\spacy\util.py:910: UserWarning: [W095] Model 'en_core_web_sm' (3.6.0) was trained with spaCy v3.6.0 and may not be 100% compatible with the current version (3.8.3). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing output/all-year/control/high:   0%|          | 0/3600 [00:00<?, ?it/s]
# Processing output/all-year/control/low:   0%|          | 0/3600 [00:00<?, ?it/s]

# %%
# %run step7.4_control_combined.all-year.cosine.mpnet.py
# Out:
# Processing file: abuse_synthetic_breadth_50_round1.1.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 1 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.1.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6761434195918368
# Processing file: abuse_synthetic_breadth_50_round1.10.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 10 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.10.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7114064987755102
# Processing file: abuse_synthetic_breadth_50_round1.100.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 100 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.100.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6923614359183674
# Processing file: abuse_synthetic_breadth_50_round1.11.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 11 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.11.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7081712808163265
# Processing file: abuse_synthetic_breadth_50_round1.12.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 12 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.12.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6418834906122449
# Processing file: abuse_synthetic_breadth_50_round1.13.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 13 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.13.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6717853991836735
# Processing file: abuse_synthetic_breadth_50_round1.14.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 14 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.14.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6786294963265307
# Processing file: abuse_synthetic_breadth_50_round1.15.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 15 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.15.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6704527657142858
# Processing file: abuse_synthetic_breadth_50_round1.16.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 16 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.16.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6841946465306122
# Processing file: abuse_synthetic_breadth_50_round1.17.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 17 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.17.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7037022832653061
# Processing file: abuse_synthetic_breadth_50_round1.18.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 18 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.18.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6702802865306122
# Processing file: abuse_synthetic_breadth_50_round1.19.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 19 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.19.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6607679469387754
# Processing file: abuse_synthetic_breadth_50_round1.2.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 2 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.2.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6781824832653061
# Processing file: abuse_synthetic_breadth_50_round1.20.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 20 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.20.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6617540244897959
# Processing file: abuse_synthetic_breadth_50_round1.21.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 21 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.21.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6943039232653061
# Processing file: abuse_synthetic_breadth_50_round1.22.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 22 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.22.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6555730563265306
# Processing file: abuse_synthetic_breadth_50_round1.23.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 23 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.23.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6863135314285714
# Processing file: abuse_synthetic_breadth_50_round1.24.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 24 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.24.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7121327673469389
# Processing file: abuse_synthetic_breadth_50_round1.25.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 25 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.25.tsv_cds_mpnet, Avg cosine dissimilarity: 0.731065146122449
# Processing file: abuse_synthetic_breadth_50_round1.26.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 26 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.26.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7103557322448979
# Processing file: abuse_synthetic_breadth_50_round1.27.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 27 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.27.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6906848563265305
# Processing file: abuse_synthetic_breadth_50_round1.28.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 28 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.28.tsv_cds_mpnet, Avg cosine dissimilarity: 0.655616506122449
# Processing file: abuse_synthetic_breadth_50_round1.29.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 29 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.29.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6790796955102041
# Processing file: abuse_synthetic_breadth_50_round1.3.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 3 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.3.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6702687983673469
# Processing file: abuse_synthetic_breadth_50_round1.30.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 30 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.30.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6688811420408164
# Processing file: abuse_synthetic_breadth_50_round1.31.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 31 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.31.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6531689526530613
# Processing file: abuse_synthetic_breadth_50_round1.32.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 32 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.32.tsv_cds_mpnet, Avg cosine dissimilarity: 0.663409707755102
# Processing file: abuse_synthetic_breadth_50_round1.33.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 33 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.33.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6762469681632653
# Processing file: abuse_synthetic_breadth_50_round1.34.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 34 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.34.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6812408514285714
# Processing file: abuse_synthetic_breadth_50_round1.35.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 35 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.35.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7200400677551021
# Processing file: abuse_synthetic_breadth_50_round1.36.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 36 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.36.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6398020587755102
# Processing file: abuse_synthetic_breadth_50_round1.37.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 37 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.37.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6687684367346938
# Processing file: abuse_synthetic_breadth_50_round1.38.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 38 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.38.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6845677616326531
# Processing file: abuse_synthetic_breadth_50_round1.39.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 39 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.39.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6878154138775511
# Processing file: abuse_synthetic_breadth_50_round1.4.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 4 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.4.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6635705273469388
# Processing file: abuse_synthetic_breadth_50_round1.40.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 40 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.40.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6853208710204082
# Processing file: abuse_synthetic_breadth_50_round1.41.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 41 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.41.tsv_cds_mpnet, Avg cosine dissimilarity: 0.696642135510204
# Processing file: abuse_synthetic_breadth_50_round1.42.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 42 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.42.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6860470408163266
# Processing file: abuse_synthetic_breadth_50_round1.43.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 43 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.43.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6960288669387755
# Processing file: abuse_synthetic_breadth_50_round1.44.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 44 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.44.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7383329044897959
# Processing file: abuse_synthetic_breadth_50_round1.45.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 45 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.45.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6915064138775511
# Processing file: abuse_synthetic_breadth_50_round1.46.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 46 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.46.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7049624310204081
# Processing file: abuse_synthetic_breadth_50_round1.47.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 47 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.47.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6926201730612245
# Processing file: abuse_synthetic_breadth_50_round1.48.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 48 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.48.tsv_cds_mpnet, Avg cosine dissimilarity: 0.676344986122449
# Processing file: abuse_synthetic_breadth_50_round1.49.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 49 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.49.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6917487257142857
# Processing file: abuse_synthetic_breadth_50_round1.5.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 5 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.5.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6489989926530613
# Processing file: abuse_synthetic_breadth_50_round1.50.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 50 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.50.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7064003330612245
# Processing file: abuse_synthetic_breadth_50_round1.51.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 51 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.51.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7204901151020408
# Processing file: abuse_synthetic_breadth_50_round1.52.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 52 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.52.tsv_cds_mpnet, Avg cosine dissimilarity: 0.667031372244898
# Processing file: abuse_synthetic_breadth_50_round1.53.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 53 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.53.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7014422775510204
# Processing file: abuse_synthetic_breadth_50_round1.54.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 54 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.54.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6872984195918367
# Processing file: abuse_synthetic_breadth_50_round1.55.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 55 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.55.tsv_cds_mpnet, Avg cosine dissimilarity: 0.67418704
# Processing file: abuse_synthetic_breadth_50_round1.56.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 56 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.56.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6799282685714286
# Processing file: abuse_synthetic_breadth_50_round1.57.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 57 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.57.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6953669697959184
# Processing file: abuse_synthetic_breadth_50_round1.58.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 58 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.58.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6834004073469387
# Processing file: abuse_synthetic_breadth_50_round1.59.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 59 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.59.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6833560555102041
# Processing file: abuse_synthetic_breadth_50_round1.6.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 6 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.6.tsv_cds_mpnet, Avg cosine dissimilarity: 0.700077706122449
# Processing file: abuse_synthetic_breadth_50_round1.60.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 60 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.60.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7023084685714285
# Processing file: abuse_synthetic_breadth_50_round1.61.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 61 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.61.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6981510881632653
# Processing file: abuse_synthetic_breadth_50_round1.62.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 62 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.62.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7107076595918368
# Processing file: abuse_synthetic_breadth_50_round1.63.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 63 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.63.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6603875134693877
# Processing file: abuse_synthetic_breadth_50_round1.64.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 64 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.64.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7006829869387755
# Processing file: abuse_synthetic_breadth_50_round1.65.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 65 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.65.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6685983624489795
# Processing file: abuse_synthetic_breadth_50_round1.66.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 66 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.66.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6849989608163265
# Processing file: abuse_synthetic_breadth_50_round1.67.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 67 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.67.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6920095975510204
# Processing file: abuse_synthetic_breadth_50_round1.68.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 68 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.68.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7137040808163265
# Processing file: abuse_synthetic_breadth_50_round1.69.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 69 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.69.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7196909477551021
# Processing file: abuse_synthetic_breadth_50_round1.7.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 7 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.7.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6998397665306123
# Processing file: abuse_synthetic_breadth_50_round1.70.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 70 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.70.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6804561559183673
# Processing file: abuse_synthetic_breadth_50_round1.71.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 71 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.71.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6895224432653061
# Processing file: abuse_synthetic_breadth_50_round1.72.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 72 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.72.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7202819738775511
# Processing file: abuse_synthetic_breadth_50_round1.73.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 73 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.73.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7117042824489797
# Processing file: abuse_synthetic_breadth_50_round1.74.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 74 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.74.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6575819085714286
# Processing file: abuse_synthetic_breadth_50_round1.75.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 75 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.75.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6796744375510204
# Processing file: abuse_synthetic_breadth_50_round1.76.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 76 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.76.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6899954375510204
# Processing file: abuse_synthetic_breadth_50_round1.77.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 77 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.77.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6952757657142857
# Processing file: abuse_synthetic_breadth_50_round1.78.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 78 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.78.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6291700138775511
# Processing file: abuse_synthetic_breadth_50_round1.79.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 79 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.79.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6899541665306123
# Processing file: abuse_synthetic_breadth_50_round1.8.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 8 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.8.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6756708171428571
# Processing file: abuse_synthetic_breadth_50_round1.80.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 80 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.80.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7026281469387755
# Processing file: abuse_synthetic_breadth_50_round1.81.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 81 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.81.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6753776693877551
# Processing file: abuse_synthetic_breadth_50_round1.82.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 82 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.82.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6849576669387755
# Processing file: abuse_synthetic_breadth_50_round1.83.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 83 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.83.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6913041853061225
# Processing file: abuse_synthetic_breadth_50_round1.84.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 84 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.84.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6777747591836734
# Processing file: abuse_synthetic_breadth_50_round1.85.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 85 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.85.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7130570653061225
# Processing file: abuse_synthetic_breadth_50_round1.86.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 86 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.86.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7195394351020408
# Processing file: abuse_synthetic_breadth_50_round1.87.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 87 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.87.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6959641853061225
# Processing file: abuse_synthetic_breadth_50_round1.88.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 88 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.88.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6779250693877551
# Processing file: abuse_synthetic_breadth_50_round1.89.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 89 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.89.tsv_cds_mpnet, Avg cosine dissimilarity: 0.640019650612245
# Processing file: abuse_synthetic_breadth_50_round1.9.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 9 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.9.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6418668269387755
# Processing file: abuse_synthetic_breadth_50_round1.90.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 90 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.90.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7151067608163265
# Processing file: abuse_synthetic_breadth_50_round1.91.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 91 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.91.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6821329681632653
# Processing file: abuse_synthetic_breadth_50_round1.92.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 92 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.92.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6882143248979592
# Processing file: abuse_synthetic_breadth_50_round1.93.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 93 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.93.tsv_cds_mpnet, Avg cosine dissimilarity: 0.694573013877551
# Processing file: abuse_synthetic_breadth_50_round1.94.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 94 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.94.tsv_cds_mpnet, Avg cosine dissimilarity: 0.698134
# Processing file: abuse_synthetic_breadth_50_round1.95.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 95 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.95.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6551696946938775
# Processing file: abuse_synthetic_breadth_50_round1.96.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 96 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.96.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6837985567346938
# Processing file: abuse_synthetic_breadth_50_round1.97.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 97 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.97.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6640938048979592
# Processing file: abuse_synthetic_breadth_50_round1.98.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 98 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.98.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6949596930612245
# Processing file: abuse_synthetic_breadth_50_round1.99.tsv_cds_mpnet | Term: abuse | Round: 1 | Repeat: 99 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round1.99.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6445256832653061
# Processing file: abuse_synthetic_breadth_50_round2.1.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 1 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.1.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6761434195918368
# Processing file: abuse_synthetic_breadth_50_round2.10.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 10 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.10.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7114064987755102
# Processing file: abuse_synthetic_breadth_50_round2.100.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 100 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.100.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6923614359183674
# Processing file: abuse_synthetic_breadth_50_round2.11.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 11 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.11.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7081712808163265
# Processing file: abuse_synthetic_breadth_50_round2.12.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 12 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.12.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6418834906122449
# Processing file: abuse_synthetic_breadth_50_round2.13.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 13 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.13.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6717853991836735
# Processing file: abuse_synthetic_breadth_50_round2.14.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 14 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.14.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6786294963265307
# Processing file: abuse_synthetic_breadth_50_round2.15.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 15 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.15.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6704527657142858
# Processing file: abuse_synthetic_breadth_50_round2.16.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 16 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.16.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6841946465306122
# Processing file: abuse_synthetic_breadth_50_round2.17.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 17 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.17.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7037022832653061
# Processing file: abuse_synthetic_breadth_50_round2.18.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 18 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.18.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6702802865306122
# Processing file: abuse_synthetic_breadth_50_round2.19.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 19 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.19.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6607679469387754
# Processing file: abuse_synthetic_breadth_50_round2.2.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 2 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.2.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6781824832653061
# Processing file: abuse_synthetic_breadth_50_round2.20.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 20 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.20.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6617540244897959
# Processing file: abuse_synthetic_breadth_50_round2.21.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 21 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.21.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6943039232653061
# Processing file: abuse_synthetic_breadth_50_round2.22.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 22 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.22.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6555730563265306
# Processing file: abuse_synthetic_breadth_50_round2.23.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 23 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.23.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6863135314285714
# Processing file: abuse_synthetic_breadth_50_round2.24.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 24 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.24.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7121327673469389
# Processing file: abuse_synthetic_breadth_50_round2.25.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 25 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.25.tsv_cds_mpnet, Avg cosine dissimilarity: 0.731065146122449
# Processing file: abuse_synthetic_breadth_50_round2.26.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 26 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.26.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7103557322448979
# Processing file: abuse_synthetic_breadth_50_round2.27.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 27 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.27.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6906848563265305
# Processing file: abuse_synthetic_breadth_50_round2.28.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 28 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.28.tsv_cds_mpnet, Avg cosine dissimilarity: 0.655616506122449
# Processing file: abuse_synthetic_breadth_50_round2.29.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 29 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.29.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6790796955102041
# Processing file: abuse_synthetic_breadth_50_round2.3.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 3 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.3.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6702687983673469
# Processing file: abuse_synthetic_breadth_50_round2.30.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 30 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.30.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6688811420408164
# Processing file: abuse_synthetic_breadth_50_round2.31.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 31 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.31.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6531689526530613
# Processing file: abuse_synthetic_breadth_50_round2.32.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 32 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.32.tsv_cds_mpnet, Avg cosine dissimilarity: 0.663409707755102
# Processing file: abuse_synthetic_breadth_50_round2.33.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 33 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.33.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6762469681632653
# Processing file: abuse_synthetic_breadth_50_round2.34.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 34 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.34.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6812408514285714
# Processing file: abuse_synthetic_breadth_50_round2.35.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 35 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.35.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7200400677551021
# Processing file: abuse_synthetic_breadth_50_round2.36.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 36 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.36.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6398020587755102
# Processing file: abuse_synthetic_breadth_50_round2.37.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 37 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.37.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6687684367346938
# Processing file: abuse_synthetic_breadth_50_round2.38.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 38 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.38.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6845677616326531
# Processing file: abuse_synthetic_breadth_50_round2.39.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 39 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.39.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6878154138775511
# Processing file: abuse_synthetic_breadth_50_round2.4.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 4 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.4.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6635705273469388
# Processing file: abuse_synthetic_breadth_50_round2.40.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 40 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.40.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6853208710204082
# Processing file: abuse_synthetic_breadth_50_round2.41.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 41 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.41.tsv_cds_mpnet, Avg cosine dissimilarity: 0.696642135510204
# Processing file: abuse_synthetic_breadth_50_round2.42.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 42 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.42.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6860470408163266
# Processing file: abuse_synthetic_breadth_50_round2.43.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 43 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.43.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6960288669387755
# Processing file: abuse_synthetic_breadth_50_round2.44.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 44 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.44.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7383329044897959
# Processing file: abuse_synthetic_breadth_50_round2.45.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 45 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.45.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6915064138775511
# Processing file: abuse_synthetic_breadth_50_round2.46.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 46 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.46.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7049624310204081
# Processing file: abuse_synthetic_breadth_50_round2.47.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 47 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.47.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6926201730612245
# Processing file: abuse_synthetic_breadth_50_round2.48.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 48 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.48.tsv_cds_mpnet, Avg cosine dissimilarity: 0.676344986122449
# Processing file: abuse_synthetic_breadth_50_round2.49.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 49 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.49.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6917487257142857
# Processing file: abuse_synthetic_breadth_50_round2.5.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 5 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.5.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6489989926530613
# Processing file: abuse_synthetic_breadth_50_round2.50.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 50 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.50.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7064003330612245
# Processing file: abuse_synthetic_breadth_50_round2.51.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 51 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.51.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7204901151020408
# Processing file: abuse_synthetic_breadth_50_round2.52.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 52 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.52.tsv_cds_mpnet, Avg cosine dissimilarity: 0.667031372244898
# Processing file: abuse_synthetic_breadth_50_round2.53.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 53 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.53.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7014422775510204
# Processing file: abuse_synthetic_breadth_50_round2.54.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 54 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.54.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6872984195918367
# Processing file: abuse_synthetic_breadth_50_round2.55.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 55 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.55.tsv_cds_mpnet, Avg cosine dissimilarity: 0.67418704
# Processing file: abuse_synthetic_breadth_50_round2.56.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 56 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.56.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6799282685714286
# Processing file: abuse_synthetic_breadth_50_round2.57.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 57 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.57.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6953669697959184
# Processing file: abuse_synthetic_breadth_50_round2.58.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 58 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.58.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6834004073469387
# Processing file: abuse_synthetic_breadth_50_round2.59.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 59 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.59.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6833560555102041
# Processing file: abuse_synthetic_breadth_50_round2.6.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 6 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.6.tsv_cds_mpnet, Avg cosine dissimilarity: 0.700077706122449
# Processing file: abuse_synthetic_breadth_50_round2.60.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 60 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.60.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7023084685714285
# Processing file: abuse_synthetic_breadth_50_round2.61.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 61 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.61.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6981510881632653
# Processing file: abuse_synthetic_breadth_50_round2.62.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 62 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.62.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7107076595918368
# Processing file: abuse_synthetic_breadth_50_round2.63.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 63 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.63.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6603875134693877
# Processing file: abuse_synthetic_breadth_50_round2.64.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 64 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.64.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7006829869387755
# Processing file: abuse_synthetic_breadth_50_round2.65.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 65 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.65.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6685983624489795
# Processing file: abuse_synthetic_breadth_50_round2.66.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 66 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.66.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6849989608163265
# Processing file: abuse_synthetic_breadth_50_round2.67.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 67 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.67.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6920095975510204
# Processing file: abuse_synthetic_breadth_50_round2.68.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 68 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.68.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7137040808163265
# Processing file: abuse_synthetic_breadth_50_round2.69.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 69 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.69.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7196909477551021
# Processing file: abuse_synthetic_breadth_50_round2.7.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 7 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.7.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6998397665306123
# Processing file: abuse_synthetic_breadth_50_round2.70.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 70 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.70.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6804561559183673
# Processing file: abuse_synthetic_breadth_50_round2.71.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 71 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.71.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6895224432653061
# Processing file: abuse_synthetic_breadth_50_round2.72.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 72 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.72.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7202819738775511
# Processing file: abuse_synthetic_breadth_50_round2.73.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 73 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.73.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7117042824489797
# Processing file: abuse_synthetic_breadth_50_round2.74.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 74 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.74.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6575819085714286
# Processing file: abuse_synthetic_breadth_50_round2.75.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 75 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.75.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6796744375510204
# Processing file: abuse_synthetic_breadth_50_round2.76.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 76 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.76.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6899954375510204
# Processing file: abuse_synthetic_breadth_50_round2.77.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 77 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.77.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6952757657142857
# Processing file: abuse_synthetic_breadth_50_round2.78.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 78 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.78.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6291700138775511
# Processing file: abuse_synthetic_breadth_50_round2.79.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 79 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.79.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6899541665306123
# Processing file: abuse_synthetic_breadth_50_round2.8.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 8 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.8.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6756708171428571
# Processing file: abuse_synthetic_breadth_50_round2.80.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 80 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.80.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7026281469387755
# Processing file: abuse_synthetic_breadth_50_round2.81.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 81 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.81.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6753776693877551
# Processing file: abuse_synthetic_breadth_50_round2.82.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 82 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.82.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6849576669387755
# Processing file: abuse_synthetic_breadth_50_round2.83.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 83 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.83.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6913041853061225
# Processing file: abuse_synthetic_breadth_50_round2.84.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 84 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.84.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6777747591836734
# Processing file: abuse_synthetic_breadth_50_round2.85.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 85 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.85.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7130570653061225
# Processing file: abuse_synthetic_breadth_50_round2.86.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 86 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.86.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7195394351020408
# Processing file: abuse_synthetic_breadth_50_round2.87.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 87 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.87.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6959641853061225
# Processing file: abuse_synthetic_breadth_50_round2.88.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 88 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.88.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6779250693877551
# Processing file: abuse_synthetic_breadth_50_round2.89.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 89 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.89.tsv_cds_mpnet, Avg cosine dissimilarity: 0.640019650612245
# Processing file: abuse_synthetic_breadth_50_round2.9.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 9 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.9.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6418668269387755
# Processing file: abuse_synthetic_breadth_50_round2.90.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 90 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.90.tsv_cds_mpnet, Avg cosine dissimilarity: 0.7151067608163265
# Processing file: abuse_synthetic_breadth_50_round2.91.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 91 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.91.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6821329681632653
# Processing file: abuse_synthetic_breadth_50_round2.92.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 92 | Inj Ratio: 50
# Successfully processed file: abuse_synthetic_breadth_50_round2.92.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6882143248979592
# Processing file: abuse_synthetic_breadth_50_round2.93.tsv_cds_mpnet | Term: abuse | Round: 2 | Repeat: 93 | Inj Ratio: 50
# ...
# Processing file: trauma_synthetic_breadth_50_round6.42.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 42 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.42.tsv_cds_mpnet, Avg cosine dissimilarity: 0.618429203265306
# Processing file: trauma_synthetic_breadth_50_round6.43.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 43 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.43.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6046473853061224
# Processing file: trauma_synthetic_breadth_50_round6.44.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 44 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.44.tsv_cds_mpnet, Avg cosine dissimilarity: 0.5944135624489796
# Processing file: trauma_synthetic_breadth_50_round6.45.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 45 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.45.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6258922375510204
# Processing file: trauma_synthetic_breadth_50_round6.46.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 46 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.46.tsv_cds_mpnet, Avg cosine dissimilarity: 0.618771495510204
# Processing file: trauma_synthetic_breadth_50_round6.47.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 47 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.47.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6353389175510203
# Processing file: trauma_synthetic_breadth_50_round6.48.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 48 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.48.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6328433632653061
# Processing file: trauma_synthetic_breadth_50_round6.49.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 49 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.49.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6148445600000001
# Processing file: trauma_synthetic_breadth_50_round6.5.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 5 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.5.tsv_cds_mpnet, Avg cosine dissimilarity: 0.5951209199999999
# Processing file: trauma_synthetic_breadth_50_round6.50.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 50 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.50.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6583868244897959
# Processing file: trauma_synthetic_breadth_50_round6.51.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 51 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.51.tsv_cds_mpnet, Avg cosine dissimilarity: 0.614397426122449
# Processing file: trauma_synthetic_breadth_50_round6.52.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 52 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.52.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6142095951020409
# Processing file: trauma_synthetic_breadth_50_round6.53.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 53 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.53.tsv_cds_mpnet, Avg cosine dissimilarity: 0.5793211697959184
# Processing file: trauma_synthetic_breadth_50_round6.54.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 54 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.54.tsv_cds_mpnet, Avg cosine dissimilarity: 0.632253010612245
# Processing file: trauma_synthetic_breadth_50_round6.55.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 55 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.55.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6152662546938775
# Processing file: trauma_synthetic_breadth_50_round6.56.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 56 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.56.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6258672873469387
# Processing file: trauma_synthetic_breadth_50_round6.57.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 57 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.57.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6439074595918368
# Processing file: trauma_synthetic_breadth_50_round6.58.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 58 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.58.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6111683420408164
# Processing file: trauma_synthetic_breadth_50_round6.59.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 59 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.59.tsv_cds_mpnet, Avg cosine dissimilarity: 0.5953685657142858
# Processing file: trauma_synthetic_breadth_50_round6.6.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 6 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.6.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6224830775510204
# Processing file: trauma_synthetic_breadth_50_round6.60.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 60 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.60.tsv_cds_mpnet, Avg cosine dissimilarity: 0.5951594889795919
# Processing file: trauma_synthetic_breadth_50_round6.61.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 61 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.61.tsv_cds_mpnet, Avg cosine dissimilarity: 0.5986111420408163
# Processing file: trauma_synthetic_breadth_50_round6.62.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 62 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.62.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6193685959183673
# Processing file: trauma_synthetic_breadth_50_round6.63.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 63 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.63.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6379629069387754
# Processing file: trauma_synthetic_breadth_50_round6.64.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 64 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.64.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6171559755102041
# Processing file: trauma_synthetic_breadth_50_round6.65.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 65 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.65.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6185209248979592
# Processing file: trauma_synthetic_breadth_50_round6.66.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 66 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.66.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6562406326530613
# Processing file: trauma_synthetic_breadth_50_round6.67.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 67 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.67.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6144534408163266
# Processing file: trauma_synthetic_breadth_50_round6.68.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 68 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.68.tsv_cds_mpnet, Avg cosine dissimilarity: 0.5910872775510204
# Processing file: trauma_synthetic_breadth_50_round6.69.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 69 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.69.tsv_cds_mpnet, Avg cosine dissimilarity: 0.5615389534693878
# Processing file: trauma_synthetic_breadth_50_round6.7.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 7 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.7.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6152985844897959
# Processing file: trauma_synthetic_breadth_50_round6.70.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 70 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.70.tsv_cds_mpnet, Avg cosine dissimilarity: 0.637527493877551
# Processing file: trauma_synthetic_breadth_50_round6.71.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 71 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.71.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6156271689795918
# Processing file: trauma_synthetic_breadth_50_round6.72.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 72 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.72.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6270756457142858
# Processing file: trauma_synthetic_breadth_50_round6.73.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 73 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.73.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6089818816326531
# Processing file: trauma_synthetic_breadth_50_round6.74.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 74 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.74.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6099045208163265
# Processing file: trauma_synthetic_breadth_50_round6.75.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 75 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.75.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6364720334693879
# Processing file: trauma_synthetic_breadth_50_round6.76.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 76 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.76.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6285358032653061
# Processing file: trauma_synthetic_breadth_50_round6.77.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 77 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.77.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6141702097959183
# Processing file: trauma_synthetic_breadth_50_round6.78.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 78 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.78.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6215560587755102
# Processing file: trauma_synthetic_breadth_50_round6.79.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 79 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.79.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6205663787755101
# Processing file: trauma_synthetic_breadth_50_round6.8.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 8 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.8.tsv_cds_mpnet, Avg cosine dissimilarity: 0.5866682228571428
# Processing file: trauma_synthetic_breadth_50_round6.80.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 80 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.80.tsv_cds_mpnet, Avg cosine dissimilarity: 0.590057542857143
# Processing file: trauma_synthetic_breadth_50_round6.81.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 81 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.81.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6088964089795919
# Processing file: trauma_synthetic_breadth_50_round6.82.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 82 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.82.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6212891142857143
# Processing file: trauma_synthetic_breadth_50_round6.83.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 83 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.83.tsv_cds_mpnet, Avg cosine dissimilarity: 0.5980679804081633
# Processing file: trauma_synthetic_breadth_50_round6.84.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 84 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.84.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6231038922448979
# Processing file: trauma_synthetic_breadth_50_round6.85.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 85 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.85.tsv_cds_mpnet, Avg cosine dissimilarity: 0.5885018424489796
# Processing file: trauma_synthetic_breadth_50_round6.86.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 86 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.86.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6352735624489796
# Processing file: trauma_synthetic_breadth_50_round6.87.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 87 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.87.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6334074008163265
# Processing file: trauma_synthetic_breadth_50_round6.88.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 88 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.88.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6425120367346938
# Processing file: trauma_synthetic_breadth_50_round6.89.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 89 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.89.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6156138416326531
# Processing file: trauma_synthetic_breadth_50_round6.9.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 9 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.9.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6017091314285715
# Processing file: trauma_synthetic_breadth_50_round6.90.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 90 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.90.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6384827134693877
# Processing file: trauma_synthetic_breadth_50_round6.91.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 91 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.91.tsv_cds_mpnet, Avg cosine dissimilarity: 0.5974117453061224
# Processing file: trauma_synthetic_breadth_50_round6.92.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 92 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.92.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6125050734693878
# Processing file: trauma_synthetic_breadth_50_round6.93.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 93 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.93.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6251288946938774
# Processing file: trauma_synthetic_breadth_50_round6.94.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 94 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.94.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6085356032653062
# Processing file: trauma_synthetic_breadth_50_round6.95.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 95 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.95.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6113978424489795
# Processing file: trauma_synthetic_breadth_50_round6.96.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 96 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.96.tsv_cds_mpnet, Avg cosine dissimilarity: 0.5975354628571429
# Processing file: trauma_synthetic_breadth_50_round6.97.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 97 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.97.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6158729836734693
# Processing file: trauma_synthetic_breadth_50_round6.98.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 98 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.98.tsv_cds_mpnet, Avg cosine dissimilarity: 0.5942166824489796
# Processing file: trauma_synthetic_breadth_50_round6.99.tsv_cds_mpnet | Term: trauma | Round: 6 | Repeat: 99 | Inj Ratio: 50
# Successfully processed file: trauma_synthetic_breadth_50_round6.99.tsv_cds_mpnet, Avg cosine dissimilarity: 0.6208754946938776
# Saved final combined results to: output/control_final_combined.all-year.cds_mpnet.csv
# Processing completed.

# %%
# %run step7.5_plot_all-year_breadth-index_control.py
# Out:
# Successfully read data from CSV file.
# C:\Users\naomi\OneDrive\COMP80004_PhDResearch\RESEARCH\PROJECTS\3_evaluation+validation - ACL 2025\ICL\2_breadth\step7.5_plot_all-year_breadth-index_control.py:59: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.errorbar(sorted_data['round_number'], sorted_data['cosine_dissim_mean'],
# C:\Users\naomi\OneDrive\COMP80004_PhDResearch\RESEARCH\PROJECTS\3_evaluation+validation - ACL 2025\ICL\2_breadth\step7.5_plot_all-year_breadth-index_control.py:59: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-" (-> marker='o'). The keyword argument will take precedence.
#   ax.errorbar(sorted_data['round_number'], sorted_data['cosine_dissim_mean'],

# %% [markdown]
# # End of script

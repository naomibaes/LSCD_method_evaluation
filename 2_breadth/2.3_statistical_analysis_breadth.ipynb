# %% [markdown]
# Author: Naomi Baes and Chat GPT

# %% [markdown]
# ## APD

# %%
# %run step6_plot1_APD_analysis_baseline.py

# %% [markdown]
# %run step6_plot2_APD_analysis_baseline.py

# %% [markdown]
# ## MEM (5-year)

# %%
# %run step6_5-year_mem_analysis_baseline.py
# Out:
# c:\Users\naomi\anaconda3\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2238: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\naomi\anaconda3\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2238: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# Null Model Summary:
#              Mixed Linear Model Regression Results
# ================================================================
# Model:            MixedLM Dependent Variable: cosine_dissim_mean
# No. Observations: 360     Method:             REML
# No. Groups:       6       Scale:              0.0009
# Min. group size:  60      Log-Likelihood:     733.1287
# Max. group size:  60      Converged:          Yes
# Mean group size:  60.0
# ------------------------------------------------------------------
#                Coef.   Std.Err.     z      P>|z|   [0.025   0.975]
# ------------------------------------------------------------------
# Intercept      0.644      0.013   49.904   0.000    0.618    0.669
# Group Var      0.001      0.021
# ================================================================
#
# ICC for 'term': 0.5179196513733002
# Full Model Summary:
#              Mixed Linear Model Regression Results
# ================================================================
# Model:            MixedLM Dependent Variable: cosine_dissim_mean
# No. Observations: 360     Method:             REML
# No. Groups:       6       Scale:              0.0008
# Min. group size:  60      Log-Likelihood:     742.7401
# Max. group size:  60      Converged:          Yes
# Mean group size:  60.0
# -----------------------------------------------------------------
#                    Coef.  Std.Err.    z     P>|z|  [0.025  0.975]
# -----------------------------------------------------------------
# Intercept          0.619     0.013  46.547  0.000   0.593   0.645
# inj_ratio[T.20]    0.018     0.005   3.471  0.001   0.008   0.028
# inj_ratio[T.40]    0.028     0.005   5.551  0.000   0.018   0.038
# inj_ratio[T.60]    0.033     0.005   6.550  0.000   0.023   0.043
# inj_ratio[T.80]    0.036     0.005   7.035  0.000   0.026   0.046
# inj_ratio[T.100]   0.031     0.005   6.024  0.000   0.021   0.041
# Group Var          0.001     0.023
# ================================================================
# c:\Users\naomi\anaconda3\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2238: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# Model with Epoch Summary:
#                       Mixed Linear Model Regression Results
# =================================================================================
# Model:                   MixedLM      Dependent Variable:      cosine_dissim_mean
# No. Observations:        360          Method:                  REML
# No. Groups:              6            Scale:                   0.0008
# Min. group size:         60           Log-Likelihood:          582.9908
# Max. group size:         60           Converged:               Yes
# Mean group size:         60.0
# ---------------------------------------------------------------------------------
#                                        Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------------------
# Intercept                               0.634    0.017 36.956 0.000  0.600  0.668
# inj_ratio[T.20]                         0.019    0.016  1.189 0.234 -0.012  0.051
# inj_ratio[T.40]                         0.030    0.016  1.877 0.061 -0.001  0.062
# inj_ratio[T.60]                         0.029    0.016  1.824 0.068 -0.002  0.061
# inj_ratio[T.80]                         0.033    0.016  2.073 0.038  0.002  0.065
# inj_ratio[T.100]                        0.026    0.016  1.597 0.110 -0.006  0.057
# C(epoch)[T.1975-1979]                  -0.022    0.016 -1.354 0.176 -0.053  0.010
# C(epoch)[T.1980-1984]                  -0.021    0.016 -1.289 0.197 -0.052  0.011
# C(epoch)[T.1985-1989]                  -0.007    0.016 -0.438 0.661 -0.039  0.025
# C(epoch)[T.1990-1994]                  -0.014    0.016 -0.864 0.388 -0.046  0.018
# C(epoch)[T.1995-1999]                  -0.023    0.016 -1.427 0.154 -0.055  0.009
# C(epoch)[T.2000-2004]                  -0.017    0.016 -1.065 0.287 -0.049  0.014
# C(epoch)[T.2005-2009]                  -0.017    0.016 -1.079 0.280 -0.049  0.014
# C(epoch)[T.2010-2014]                  -0.009    0.016 -0.566 0.572 -0.041  0.022
# C(epoch)[T.2015-2019]                  -0.016    0.016 -0.966 0.334 -0.047  0.016
# inj_ratio[T.20]:C(epoch)[T.1975-1979]   0.003    0.023  0.113 0.910 -0.042  0.047
# inj_ratio[T.40]:C(epoch)[T.1975-1979]   0.005    0.023  0.233 0.816 -0.039  0.050
# inj_ratio[T.60]:C(epoch)[T.1975-1979]   0.010    0.023  0.429 0.668 -0.035  0.055
# inj_ratio[T.80]:C(epoch)[T.1975-1979]   0.010    0.023  0.456 0.649 -0.034  0.055
# inj_ratio[T.100]:C(epoch)[T.1975-1979]  0.014    0.023  0.605 0.545 -0.031  0.059
# inj_ratio[T.20]:C(epoch)[T.1980-1984]   0.002    0.023  0.104 0.917 -0.042  0.047
# inj_ratio[T.40]:C(epoch)[T.1980-1984]   0.004    0.023  0.171 0.865 -0.041  0.049
# inj_ratio[T.60]:C(epoch)[T.1980-1984]   0.019    0.023  0.840 0.401 -0.026  0.064
# inj_ratio[T.80]:C(epoch)[T.1980-1984]   0.018    0.023  0.768 0.442 -0.027  0.062
# inj_ratio[T.100]:C(epoch)[T.1980-1984]  0.023    0.023  1.017 0.309 -0.022  0.068
# inj_ratio[T.20]:C(epoch)[T.1985-1989]  -0.007    0.023 -0.294 0.768 -0.051  0.038
# inj_ratio[T.40]:C(epoch)[T.1985-1989]  -0.013    0.023 -0.566 0.572 -0.058  0.032
# inj_ratio[T.60]:C(epoch)[T.1985-1989]  -0.009    0.023 -0.384 0.701 -0.053  0.036
# inj_ratio[T.80]:C(epoch)[T.1985-1989]  -0.010    0.023 -0.446 0.655 -0.055  0.035
# inj_ratio[T.100]:C(epoch)[T.1985-1989] -0.010    0.023 -0.423 0.673 -0.054  0.035
# inj_ratio[T.20]:C(epoch)[T.1990-1994]   0.000    0.023  0.013 0.990 -0.044  0.045
# inj_ratio[T.40]:C(epoch)[T.1990-1994]   0.001    0.023  0.059 0.953 -0.043  0.046
# inj_ratio[T.60]:C(epoch)[T.1990-1994]   0.010    0.023  0.423 0.672 -0.035  0.054
# inj_ratio[T.80]:C(epoch)[T.1990-1994]   0.007    0.023  0.297 0.766 -0.038  0.052
# inj_ratio[T.100]:C(epoch)[T.1990-1994]  0.012    0.023  0.526 0.599 -0.033  0.057
# inj_ratio[T.20]:C(epoch)[T.1995-1999]  -0.002    0.023 -0.104 0.917 -0.047  0.042
# inj_ratio[T.40]:C(epoch)[T.1995-1999]  -0.002    0.023 -0.105 0.917 -0.047  0.042
# inj_ratio[T.60]:C(epoch)[T.1995-1999]   0.003    0.023  0.152 0.880 -0.041  0.048
# inj_ratio[T.80]:C(epoch)[T.1995-1999]   0.004    0.023  0.183 0.855 -0.041  0.049
# inj_ratio[T.100]:C(epoch)[T.1995-1999]  0.011    0.023  0.475 0.635 -0.034  0.056
# inj_ratio[T.20]:C(epoch)[T.2000-2004]  -0.009    0.023 -0.414 0.679 -0.054  0.035
# inj_ratio[T.40]:C(epoch)[T.2000-2004]  -0.015    0.023 -0.661 0.509 -0.060  0.030
# inj_ratio[T.60]:C(epoch)[T.2000-2004]  -0.018    0.023 -0.781 0.435 -0.063  0.027
# inj_ratio[T.80]:C(epoch)[T.2000-2004]  -0.025    0.023 -1.114 0.265 -0.070  0.019
# inj_ratio[T.100]:C(epoch)[T.2000-2004] -0.033    0.023 -1.454 0.146 -0.078  0.012
# inj_ratio[T.20]:C(epoch)[T.2005-2009]  -0.001    0.023 -0.028 0.977 -0.045  0.044
# inj_ratio[T.40]:C(epoch)[T.2005-2009]   0.006    0.023  0.255 0.799 -0.039  0.051
# inj_ratio[T.60]:C(epoch)[T.2005-2009]   0.016    0.023  0.699 0.485 -0.029  0.061
# inj_ratio[T.80]:C(epoch)[T.2005-2009]   0.019    0.023  0.832 0.405 -0.026  0.064
# inj_ratio[T.100]:C(epoch)[T.2005-2009]  0.026    0.023  1.118 0.264 -0.019  0.070
# inj_ratio[T.20]:C(epoch)[T.2010-2014]  -0.002    0.023 -0.092 0.927 -0.047  0.043
# inj_ratio[T.40]:C(epoch)[T.2010-2014]  -0.007    0.023 -0.285 0.776 -0.051  0.038
# inj_ratio[T.60]:C(epoch)[T.2010-2014]  -0.000    0.023 -0.005 0.996 -0.045  0.045
# inj_ratio[T.80]:C(epoch)[T.2010-2014]  -0.008    0.023 -0.333 0.739 -0.052  0.037
# inj_ratio[T.100]:C(epoch)[T.2010-2014] -0.008    0.023 -0.342 0.732 -0.053  0.037
# inj_ratio[T.20]:C(epoch)[T.2015-2019]   0.000    0.023  0.017 0.986 -0.044  0.045
# inj_ratio[T.40]:C(epoch)[T.2015-2019]  -0.000    0.023 -0.021 0.983 -0.045  0.044
# inj_ratio[T.60]:C(epoch)[T.2015-2019]   0.007    0.023  0.300 0.764 -0.038  0.052
# inj_ratio[T.80]:C(epoch)[T.2015-2019]   0.008    0.023  0.352 0.724 -0.037  0.053
# inj_ratio[T.100]:C(epoch)[T.2015-2019]  0.014    0.023  0.592 0.554 -0.031  0.058
# Group Var                               0.001    0.023
# =================================================================================
#
# Likelihood Ratio Test Statistic: -319.49861578470814, p-value: 1.0
# Shapiro-Wilk test for normality: Statistic=0.9573707580566406, p-value=1.023363083163531e-08
# Levene’s test for homogeneity of variances: Statistic=13.645686989692898, p-value=0.00023751789179683033
# OLS Model Summary:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     cosine_dissim_mean   R-squared:                       0.087
# Model:                            OLS   Adj. R-squared:                  0.074
# Method:                 Least Squares   F-statistic:                     6.715
# Date:                Wed, 08 Jan 2025   Prob (F-statistic):           5.39e-06
# Time:                        14:18:46   Log-Likelihood:                 650.08
# No. Observations:                 360   AIC:                            -1288.
# Df Residuals:                     354   BIC:                            -1265.
# Df Model:                           5
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            0.6194      0.005    119.643      0.000       0.609       0.630
# inj_ratio[T.20]      0.0176      0.007      2.407      0.017       0.003       0.032
# inj_ratio[T.40]      0.0282      0.007      3.849      0.000       0.014       0.043
# inj_ratio[T.60]      0.0333      0.007      4.541      0.000       0.019       0.048
# inj_ratio[T.80]      0.0357      0.007      4.878      0.000       0.021       0.050
# inj_ratio[T.100]     0.0306      0.007      4.177      0.000       0.016       0.045
# ==============================================================================
# Omnibus:                       26.674   Durbin-Watson:                   2.656
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               33.076
# Skew:                           0.600   Prob(JB):                     6.57e-08
# Kurtosis:                       3.875   Cond. No.                         6.85
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## ANOVA

# %%
#%run step6_5-year_ANOVA_analysis.py

# %%
# %run plot2_ANOVA_analysis_baseline.py # fix

# %% [markdown]
# # End of notebook

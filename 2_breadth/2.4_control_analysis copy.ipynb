# %% [markdown]
# # Control analysis
#
# Authors: Naomi Baes and Chat GPT

# %% [markdown]
# ## 5-year random stratified random sampling strategy

# %%
# Get sentences from 5-year samples and put in one files grouped by condition, target, epoch
# %run step7.1_control_shuffle_5-year.py
# Out:
# Files have been successfully grouped, split by natural and synthetic, and saved.

# %%
# The script generates randomized uniform samples of natural and synthetic sentences for specified targets, time intervals, and conditions, saving the results into separate 
# files without column headers and differentiating injection ratio rounds in the file names for later aggregation.
# %run step7.2_control_randomly_sample_sentences_5-year.py
# Out:
# 100%|██████████| 60/60 [00:08<00:00,  7.24it/s]

# %%
# %run step7.3_control_process_sentences_5-year.cosine_mpnet.py
# Out:
# c:\Users\naomi\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:1150: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# c:\Users\naomi\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:1150: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing directory: output/5-year.cosine/control
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.1.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.58s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.1.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.10.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.08s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.10.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.2.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.18it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.2.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.3.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.01s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.3.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.4.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.02it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.4.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.5.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.5.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.6.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.02it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.6.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.7.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.02it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.7.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.8.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.00s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.8.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.9.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.13s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round1.9.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.1.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.10s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.1.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.10.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.15s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.10.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.2.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.02it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.2.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.3.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.08s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.3.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.4.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.08s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.4.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.5.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.04it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.5.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.6.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.59s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.6.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.7.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.60s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.7.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.8.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.00s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.8.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.9.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.22s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round2.9.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.1.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.22s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.1.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.10.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.37s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.10.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.2.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.47s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.2.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.3.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.39s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.3.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.4.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.11s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.4.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.5.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.10s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.5.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.6.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.27s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.6.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.7.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.22s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.7.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.8.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.15s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.8.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.9.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.57s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round3.9.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.1.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.13s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.1.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.10.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.36s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.10.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.2.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.12s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.2.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.3.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.30s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.3.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.4.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.26s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.4.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.5.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.07s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.5.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.6.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.12s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.6.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.7.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.12s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.7.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.8.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.21s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.8.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.9.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.55s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round4.9.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.1.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.16s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.1.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.10.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.41s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.10.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.2.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.22s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.2.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.3.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.46s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.3.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.4.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.22s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.4.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.5.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.12s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.5.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.6.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.29s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.6.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.7.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.19s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.7.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.8.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.23s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.8.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.9.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.36s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round5.9.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.1.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.42s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.1.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.10.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.34s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.10.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.2.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.14s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.2.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.3.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.24s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.3.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.4.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.22s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.4.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.5.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.13s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.5.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.6.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.16s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.6.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.7.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.20s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.7.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.8.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.27s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.8.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.9.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.33s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1970-1974_synthetic_50_round6.9.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.1.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.07s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.1.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.10.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.25s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.10.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.2.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.23it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.2.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.3.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.07it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.3.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.4.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.75s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.4.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.5.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.22it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.5.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.6.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.38s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.6.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.7.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.7.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.8.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.00s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.8.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.9.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round1.9.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round2.1.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.04it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round2.1.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round2.10.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.06s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round2.10.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round2.2.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.24it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round2.2.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round2.3.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.40it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round2.3.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round2.4.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.79s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round2.4.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round2.5.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.39it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round2.5.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round2.6.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.22s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round2.6.tsv_cds_mpnet
# Processing file: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_round2.7.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.04it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/5-year.cosine/control\abuse_1975-1979_synthetic_50_
1_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round3.2_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round3.3_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round3.4_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round3.5_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round3.6_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round3.7_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round3.8_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round3.9_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round4.10_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round4.1_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round4.2_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round4.3_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round4.4_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round4.5_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round4.6_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round4.7_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round4.8_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round4.9_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round5.10_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round5.1_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round5.2_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round5.3_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round5.4_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round5.5_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round5.6_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round5.7_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round5.8_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round5.9_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round6.10_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round6.1_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round6.2_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round6.3_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round6.4_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round6.5_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round6.6_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round6.7_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round6.8_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2010-2014_synthetic_50_round6.9_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round1.10_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round1.1_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round1.2_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round1.3_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round1.4_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round1.5_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round1.6_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round1.7_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round1.8_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round1.9_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round2.10_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round2.1_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round2.2_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round2.3_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round2.4_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round2.5_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round2.6_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round2.7_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round2.8_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round2.9_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round3.10_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round3.1_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round3.2_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round3.3_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round3.4_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round3.5_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round3.6_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round3.7_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round3.8_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round3.9_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round4.10_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round4.1_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round4.2_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round4.3_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round4.4_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round4.5_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round4.6_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round4.7_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round4.8_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round4.9_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round5.10_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round5.1_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round5.2_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round5.3_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round5.4_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round5.5_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round5.6_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round5.7_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round5.8_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round5.9_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round6.10_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round6.1_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round6.2_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round6.3_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round6.4_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round6.5_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round6.6_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round6.7_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round6.8_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\low/trauma_2015-2019_synthetic_50_round6.9_lemmatized_collocates.csv

# %%
# %run step7.5_5-year_breadth_index_control.py
# Out:
# Processing files:   0%|          | 0/7200 [00:00<?, ?it/s]

# %% [markdown]
# ## all-year bootstrap sampling strategy

# %%
# Get sentences from all-year samples and put in one files grouped by condition, target
# %run step7.1_control_shuffle_all-year.py
# Out:
# c:\Users\naomi\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# Files have been successfully grouped, split by natural and synthetic, and saved.

# %%
# The script generates randomized uniform samples of natural and synthetic sentences for specified targets, time intervals, and conditions, saving the results into separate 
# files without column headers and differentiating injection ratio rounds in the file names for later aggregation.
# %run step7.2_control_randomly_sample_sentences_all-year.py
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# Loaded corpus from output/all-year.cosine/control\input\natural\trauma_all-year_breadth_natural.csv, first 5 rows:
#                                             sentence    label
# 0  Possible reasons for high rates of trauma and ...  natural
# 1  The present paper briefly reviews the literatu...  natural
# 2  The conference covered recent research on the ...  natural
# 3  Shared trauma, vicarious traumatization, compa...  natural
# 4  Instead, memories for sexual trauma were assoc...  natural
# Loaded corpus from output/all-year.cosine/control\input\natural\depression_all-year_breadth_natural.csv, first 5 rows:
#                                             sentence    label
# 0  However, paternal antisocial behavior moderate...  natural
# 1           Depression and anxiety were most common.  natural
# 2  After adjusting for sex, depression severity (...  natural
# 3  This paper outlines a hierarchical Bayesian fr...  natural
# 4  Mediation tests and bootstrap confidence inter...  natural
# Loaded corpus from output/all-year.cosine/control\input\natural\anxiety_all-year_breadth_natural.csv, first 5 rows:
#                                             sentence    label
# 0  The hypothesis that repressors would interpret...  natural
# 1  Children who didn't go to juku school, scored ...  natural
# 2  Spider phobia is a common form of anxiety diso...  natural
# 3  Further results demonstrate thatglobal persona...  natural
# 4  The personality inventories comprised the Trid...  natural
# Loaded corpus from output/all-year.cosine/control\input\natural\mental_health_all-year_breadth_natural.csv, first 5 rows:
#                                             sentence    label
# 0  Results from two qualitative research studies ...  natural
# 1  The relationship of analgesic medication use w...  natural
# 2  Although the major reason cited for not obtain...  natural
# 3  Poor perinatal mental_health can have detrimen...  natural
# 4  A comprehensive treatment approach for detaine...  natural
# Loaded corpus from output/all-year.cosine/control\input\natural\abuse_all-year_breadth_natural.csv, first 5 rows:
#                                             sentence    label
# 0  Adolescents have been reported to be less moti...  natural
# 1  Childhood sexual and physical abuse is relativ...  natural
# 2  The present study examined the incidence of fa...  natural
# 3  Antisocial peers and academic engagement at ag...  natural
# 4  Independent variables included demographics, a...  natural
# Loaded corpus from output/all-year.cosine/control\input\natural\mental_illness_all-year_breadth_natural.csv, first 5 rows:
#                                             sentence    label
# 0  In particular, unaccompanied refugee minors ar...  natural
# 1  This study explored how individual differences...  natural
# 2  It is well documented that mental_illness impa...  natural
# 3  To review perceptions of barriers to receiving...  natural
# 4  Furthermore, workers who reported to have more...  natural
# Loaded corpus from output/all-year.cosine/control\input\synthetic\anxiety_all-year_breadth_synthetic.csv, first 5 rows:
#                                             sentence                    label
# 0  Basic to Freuds essay on Jensens romance is th...       synthetic_delusion
# 1  Group performance showed considerable overlap,...   synthetic_dissociation
# 2  anxiety and hallucination severity, cognitive ...       synthetic_delusion
# 3  anxiety professionals appear to follow rather ...  synthetic_mental_health
# 4  These results show that specific shifts of att...       synthetic_hypnosis
# Loaded corpus from output/all-year.cosine/control\input\synthetic\depression_all-year_breadth_synthetic.csv, first 5 rows:
#                                             sentence                 label
# 0  The patients' health status at follow-up was c...  synthetic_melancholy
# 1  Course and outcome are primarily dependent on ...    synthetic_delusion
# 2  depression in nursing home residents presents ...   synthetic_agitation
# 3  Previous writers have suggested a relationship...     synthetic_anxiety
# 4  The Council finds that recollections obtained ...    synthetic_hypnosis
# Loaded corpus from output/all-year.cosine/control\input\synthetic\trauma_all-year_breadth_synthetic.csv, first 5 rows:
#                                             sentence  \
# 0  The trauma between strengthening of practiced ...
# 1  A review of the literature reveals that the tr...
# 2  Following the workshops there was a reduction ...
# 3  There was no significant difference between me...
# 4  Changes for the trauma treatment were noted on...
#
#                          label
# 0       synthetic_dissociation
# 1           synthetic_delusion
# 2  synthetic_depersonalization
# 3            synthetic_anxiety
# 4           synthetic_hypnosis
# Loaded corpus from output/all-year.cosine/control\input\synthetic\mental_illness_all-year_breadth_synthetic.csv, first 5 rows:
#                                             sentence                  label
# 0  The aim of this study is to longitudinally inv...   synthetic_depression
# 1  The subjective experience of mental_illness ma...    synthetic_anhedonia
# 2  Thus, a 'trunk and branch' analogy was suggest...    synthetic_agitation
# 3  When personality and attachment measures were ...      synthetic_anxiety
# 4  Plasma NE showed a negative correlation with a...  synthetic_nervousness
# Loaded corpus from output/all-year.cosine/control\input\synthetic\mental_health_all-year_breadth_synthetic.csv, first 5 rows:
#                                             sentence  \
# 0  Clinical material is presented to demonstrate ...
# 1  I posit a dialectic of excitement and mental_h...
# 2  The resulting data were analyzed to determine ...
# 3  The secondary purpose was to examine the predi...
# 4  A 33-item mental_health Symptom Checklist (TSC...
#
#                          label
# 0  synthetic_depersonalization
# 1        synthetic_enchantment
# 2           synthetic_hypnosis
# 3         synthetic_depression
# 4             synthetic_trauma
# Loaded corpus from output/all-year.cosine/control\input\synthetic\abuse_all-year_breadth_synthetic.csv, first 5 rows:
#                                             sentence                   label
tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.56s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.11.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.12.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.74s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.12.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.13.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.70s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.13.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.14.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.35s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.14.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.15.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.60s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.15.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.16.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.63s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.16.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.17.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.93s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.17.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.18.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:04<00:00,  2.03s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.18.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.19.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.17s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.19.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.2.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.17s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.2.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.20.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.33s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.20.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.21.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.51s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.21.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.22.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.37s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.22.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.23.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.71s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.23.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.24.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.60s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.24.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.25.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:05<00:00,  2.70s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.25.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.26.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.71s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.26.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.27.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.62s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.27.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.28.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.14s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.28.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.29.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.53s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.29.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.3.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.75s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.3.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.30.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.62s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.30.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.31.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:04<00:00,  2.01s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.31.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.32.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.42s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.32.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.33.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.52s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.33.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.34.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.82s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.34.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.35.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.41s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.35.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.36.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.71s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.36.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.37.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.76s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.37.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.38.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.26s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.38.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.39.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.34s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.39.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.4.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.59s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.4.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.40.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:04<00:00,  2.14s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.40.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.41.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.56s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.41.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.42.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.62s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.42.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.43.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.45s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.43.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.44.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.46s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.44.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.45.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.80s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.45.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.46.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:04<00:00,  2.19s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.46.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.47.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.80s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.47.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.48.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.73s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.48.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.49.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.42s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.49.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.5.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.46s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.5.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.50.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.64s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.50.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.51.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.54s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.51.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.52.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.84s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.52.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.53.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.66s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.53.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.54.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.64s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.54.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.55.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.80s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.55.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\abuse_synthetic_breadth_50_round2.56.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.32s/it]
# Number of embeddings generated: 50
# ...
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.53.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.54.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.12s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.54.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.55.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.28s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.55.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.56.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.00s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.56.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.57.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.05s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.57.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.58.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.58.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.59.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.12s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.59.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.6.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.6.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.60.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.07it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.60.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.61.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.26it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.61.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.62.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.29s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.62.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.63.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.61s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.63.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.64.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.07s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.64.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.65.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.00s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.65.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.66.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.15it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.66.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.67.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.18it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.67.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.68.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.18it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.68.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.69.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.18s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.69.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.7.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.20s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.7.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.70.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.23s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.70.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.71.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.24s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.71.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.72.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.15s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.72.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.73.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:06<00:00,  3.38s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.73.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.74.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.11s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.74.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.75.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.75.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.76.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.02it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.76.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.77.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.77.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.78.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.03it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.78.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.79.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.21s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.79.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.8.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.23s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.8.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.80.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.33s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.80.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.81.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.30s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.81.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.82.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.17it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.82.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.83.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.23s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.83.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.84.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.05it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.84.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.85.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.01s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.85.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.86.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.36it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.86.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.87.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.26it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.87.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.88.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.88.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.89.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.89.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.9.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.27s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.9.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.90.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.05it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.90.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.91.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.91.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.92.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.16s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.92.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.93.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:03<00:00,  1.58s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.93.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.94.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.12s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.94.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.95.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.95.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.96.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.05it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.96.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.97.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:02<00:00,  1.03s/it]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.97.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.98.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.07it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.98.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.99.tsv
# Generating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.02it/s]
# Number of embeddings generated: 50
# Saved the dissimilarity scores to: output/all-year.cosine/control\trauma_synthetic_breadth_50_round6.99.tsv_cds_mpnet
# Processing file: output/all-year.cosine/control\warnings.log
# Generating embeddings: 100%|██████████| 335/335 [01:38<00:00,  3.40it/s]
# Number of embeddings generated: 10706
# Saved the dissimilarity scores to: output/all-year.cosine/control\warnings.log_cds_mpnet
# Processing completed.

# %% [markdown]
# # End of script

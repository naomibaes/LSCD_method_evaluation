# %% [markdown]
# Author: Naomi Baes and Chat GPT

# %% [markdown]
# # Plot cosine dissimilarity scores

# %% [markdown]
# ##### Natural data only: Plot baselines

# %%
# %run step5_plot_5-year_breadth-index_natural_baseline.py
# Out:
# Successfully read data from CSV file.

# %% [markdown]
# ## all-year.cosine

# %%
# %run step5_plot_all-year_breadth-index_baseline.py
# Out:
# Successfully read data from CSV file.
# C:\Users\naomi\OneDrive\COMP80004_PhDResearch\RESEARCH\PROJECTS\3_evaluation+validation - ACL 2025\ICL\2_breadth\step5_plot_all-year_breadth-index_baseline.py:54: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.errorbar(sorted_data['inj_ratio'], sorted_data['cosine_dissim_mean'],
# C:\Users\naomi\OneDrive\COMP80004_PhDResearch\RESEARCH\PROJECTS\3_evaluation+validation - ACL 2025\ICL\2_breadth\step5_plot_all-year_breadth-index_baseline.py:54: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-" (-> marker='o'). The keyword argument will take precedence.
#   ax.errorbar(sorted_data['inj_ratio'], sorted_data['cosine_dissim_mean'],

# %% [markdown]
# ## 5-year.cosine

# %%
# %run step5_plot_5-year_breadth-index_baseline.py
# Out:
# Successfully read data from CSV file.

# %% [markdown]
# # End of notebook

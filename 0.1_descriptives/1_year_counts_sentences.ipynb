# %% [markdown]
# **Author**: Naomi Baes and Chat GPT
#
# **Purpose**: Process context (sentence) files for specified terms and corpus, extract counts of occurrences of relevant years, aggregate these counts based on year, term, and corpus, and then write the aggregated data to a CSV for further analysis or reporting; plot to determine how large the intervals can be.
#
# **Aim**: Get year_counts_lines for all corpus and target_terms

# %% [markdown]
# ## Year-wise sentence count

# %%
# %run get_year_sentence_count.py
# Out:
# C:\Users\naomi\OneDrive\COMP80004_PhDResearch\RESEARCH\PROJECTS\3_evaluation+validation - ACL 2025\OSF\0.1_descriptives\get_year_sentence_count.py:11: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   # Check for any duplicate or unexpected counts in the year 1979
# Post-aggregation check for duplicates:
# No duplicate year entries found.

# %% [markdown]
# # Setup
#
# Filter lines by term and corpus to create the "year_counts_sentences.csv" file

# %%
# %run sentence_statistics.py
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\naomi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Header: ['sentence', 'publication_year']
# Data written to output\year_counts_sentences.csv
# Sentence statistics written to output\sentence_stats.txt

# %% [markdown]
# Get total target counts in corpus:

# %%
# %run total_target_counts.py
# Out:
# Reading data from: output/year_counts_sentences.csv
# Total sentence counts and year ranges for each target term in each corpus (entire corpus):
#   - 'abuse' in corpus 'psych': 46272 (Year range: 1970-2019)
#   - 'addiction' in corpus 'psych': 8570 (Year range: 1970-2019)
#   - 'anger' in corpus 'psych': 17494 (Year range: 1970-2019)
#   - 'anxiety' in corpus 'psych': 104486 (Year range: 1970-2019)
#   - 'automobile' in corpus 'psych': 412 (Year range: 1970-2019)
#   - 'bank' in corpus 'psych': 1296 (Year range: 1971-2019)
#   - 'bullying' in corpus 'psych': 9026 (Year range: 1971-2019)
#   - 'camera' in corpus 'psych': 822 (Year range: 1970-2019)
#   - 'car' in corpus 'psych': 2686 (Year range: 1970-2019)
#   - 'deer' in corpus 'psych': 171 (Year range: 1978-2018)
#   - 'depression' in corpus 'psych': 115430 (Year range: 1970-2019)
#   - 'distress' in corpus 'psych': 36224 (Year range: 1970-2019)
#   - 'empathy' in corpus 'psych': 9832 (Year range: 1970-2019)
# ...

# %% [markdown]
# # Plot the year_counts_sentences.csv trends to determine breadth analysis intervals

# %% [markdown]
# ##  1-year intervals

# %%
# %run plot_1-year.py
# Out:
# Plots saved to output/1-year_counts_sentences.png

# %% [markdown]
# ## 5-year intervals (for filtered candidates)

# %%
# %run plot_5-year.py
# Out:
# Plots saved to ../figures/plot_appendixA.png

# %% [markdown]
# ## 10 year intervals

# %%
# %run plot_10-year.py
# Out:
# Plots saved to output/10-year_counts_sentences.png

# %% [markdown]
# # End of notebook

# %% [markdown]
# # Control analysis
#
# Authors: Naomi Baes and Chat GPT

# %% [markdown]
# ## 5-year random stratified random sampling strategy

# %%
# Get sentences from 5-year samples and put in one files grouped by condition, target, epoch
# %run step7.1_control_shuffle_5-year.py
# Out:
# c:\Users\naomi\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# Files have been successfully grouped, split by natural and synthetic, and saved.

# %%
# The script generates randomized uniform samples of natural and synthetic sentences for specified targets, time intervals, and conditions, saving the results into separate 
# files without column headers and differentiating injection ratio rounds in the file names for later aggregation.
# %run step7.2_control_randomly_sample_sentences_5-year.py
# Out:
# 100%|██████████| 120/120 [00:16<00:00,  7.50it/s]

# %%
# %run step7.3_control_lemmatize_sentences_5-year.py
# Out:
# c:\Users\naomi\anaconda3\Lib\site-packages\spacy\util.py:910: UserWarning: [W095] Model 'en_core_web_sm' (3.6.0) was trained with spaCy v3.6.0 and may not be 100% compatible with the current version (3.8.3). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# ...
# Processing output/5-year/control/low:   0%|          | 0/3600 [00:00<?, ?it/s]

# %%
# %run step7.4_control_get_collocates_5-year.py
# Out:
# Output written to output/5-year/control/collocates\high/abuse_1970-1974_synthetic_50_round1.10_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\high/abuse_1970-1974_synthetic_50_round1.1_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\high/abuse_1970-1974_synthetic_50_round1.2_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\high/abuse_1970-1974_synthetic_50_round1.3_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\high/abuse_1970-1974_synthetic_50_round1.4_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\high/abuse_1970-1974_synthetic_50_round1.5_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\high/abuse_1970-1974_synthetic_50_round1.6_lemmatized_collocates.csv
# Output written to output/5-year/control/collocates\high/abuse_1970-1974_synthetic_50_round1.7_lemmatized_collocates.csv
# ...

# %%
# %run step7.5_control_compute_intensity-index_5-year_normalized
# Out:
# Processing files:   0%|          | 0/7200 [00:00<?, ?it/s]

# %%
# %run step7.6_control_plot_5-year_intensity-index_BOTH_normalized.py
# Out:
# Successfully read data from CSV file.

# %% [markdown]
# ## all-year bootstrap sampling strategy

# %%
# Get sentences from all-year samples and put in one files grouped by condition, target
# %run step7.1_control_shuffle_all-year.py
# Out:
# Files have been successfully grouped, split by natural and synthetic, and saved.

# %%
# The script generates randomized uniform samples of natural and synthetic sentences for specified targets, time intervals, and conditions, saving the results into separate 
# files without column headers and differentiating injection ratio rounds in the file names for later aggregation.
# %run step7.2_control_randomly_sample_sentences_all-year.py
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# Loaded corpus from output/all-year/control\input\high\natural\depression_all-year_intensity_natural.tsv, first 5 rows:
#                                             sentence    label
# 0  The fatigue dimension of the MQ remained highl...  natural
# 1  Depression and hopelessness predict myocardial...  natural
# 2  The immunological role of hardiness was ascert...  natural
# 3  Other risk factors were co-morbidity, prehisto...  natural
# 4  A total of 37 patients with remitted geriatric...  natural
# Loaded corpus from output/all-year/control\input\high\natural\anxiety_all-year_intensity_natural.tsv, first 5 rows:
#                                             sentence    label
# 0  After assessing social anxiety and depressive ...  natural
# 1  As a whole, our findings identify task coping ...  natural
# 2  Anxiety symptoms and disorders are common amon...  natural
# 3  Second, the contribution of biological pathway...  natural
# ...

# %%
# %run step7.3_control_lemmatize_sentences_all-year.py
# Out:
# c:\Users\naomi\anaconda3\Lib\site-packages\spacy\util.py:910: UserWarning: [W095] Model 'en_core_web_sm' (3.6.0) was trained with spaCy v3.6.0 and may not be 100% compatible with the current version (3.8.3). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# ...
# Processing output/all-year/control/low:   0%|          | 0/3600 [00:00<?, ?it/s]

# %%
# %run step7.4_control_get_collocates_all-year.py
# Out:
# Output written to output/all-year/control/collocates\high/abuse_synthetic_intensity_50_round1.100_lemmatized_collocates.csv
# Output written to output/all-year/control/collocates\high/abuse_synthetic_intensity_50_round1.10_lemmatized_collocates.csv
# Output written to output/all-year/control/collocates\high/abuse_synthetic_intensity_50_round1.11_lemmatized_collocates.csv
# Output written to output/all-year/control/collocates\high/abuse_synthetic_intensity_50_round1.12_lemmatized_collocates.csv
# Output written to output/all-year/control/collocates\high/abuse_synthetic_intensity_50_round1.13_lemmatized_collocates.csv
# Output written to output/all-year/control/collocates\high/abuse_synthetic_intensity_50_round1.14_lemmatized_collocates.csv
# Output written to output/all-year/control/collocates\high/abuse_synthetic_intensity_50_round1.15_lemmatized_collocates.csv
# ...

# %%
# %run step7.5_control_compute_intensity-index_all-year_normalized.py
# Out:
# Processing files:   0%|          | 0/7200 [00:00<?, ?it/s]

# %%
# %run step7.6_control_plot_all-year_intensity-index_BOTH_normalized.py
# Out:
# C:\Users\naomi\OneDrive\COMP80004_PhDResearch\RESEARCH\PROJECTS\3_evaluation+validation - ACL 2025\ICL\3_intensity\step7.6_control_plot_all-year_intensity-index_BOTH_normalized.py:58: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax1.errorbar(sorted_data['round_number'], sorted_data['avg_arousal_index_high'],
# C:\Users\naomi\OneDrive\COMP80004_PhDResearch\RESEARCH\PROJECTS\3_evaluation+validation - ACL 2025\ICL\3_intensity\step7.6_control_plot_all-year_intensity-index_BOTH_normalized.py:58: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-" (-> marker='o'). The keyword argument will take precedence.
#   ax1.errorbar(sorted_data['round_number'], sorted_data['avg_arousal_index_high'],
# ...

# %% [markdown]
# # End of script

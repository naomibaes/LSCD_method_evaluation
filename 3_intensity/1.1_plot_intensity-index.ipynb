# %% [markdown]
# **Authors: Naomi Baes and Chat GPT**
#
# *myenv (Python 3.11.9)*

# %% [markdown]
# # Plot Intensity Index

# %% [markdown]
# ### 5-year Intensity

# %%
#%run step4_plot_5-year_intensity-index_HIGH.py

# %%
#%run step4_plot_5-year_intensity-index_LOW.py

# %%
#%run step4_baseline_plot_5-year_intensity-index_BOTH.py
# %run step4_baseline_plot_5-year_intensity-index_BOTH_normalized.py
# Out:
# c:\Users\naomi\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# Successfully read data from CSV file.

# %% [markdown]
# ## all-year Intensity

# %%
#%run step4_baseline_plot_all-year_intensity-index_BOTH_SE.py
# %run step4_baseline_plot_all-year_intensity-index_BOTH_SE_normalized.py
# Out:
# C:\Users\naomi\OneDrive\COMP80004_PhDResearch\RESEARCH\PROJECTS\3_evaluation+validation - ACL 2025\ICL\3_intensity\step4_baseline_plot_all-year_intensity-index_BOTH_SE_normalized.py:62: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax1.errorbar(sorted_data['injection_ratio'], sorted_data['avg_arousal_index_high'],
# C:\Users\naomi\OneDrive\COMP80004_PhDResearch\RESEARCH\PROJECTS\3_evaluation+validation - ACL 2025\ICL\3_intensity\step4_baseline_plot_all-year_intensity-index_BOTH_SE_normalized.py:62: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-" (-> marker='o'). The keyword argument will take precedence.
#   ax1.errorbar(sorted_data['injection_ratio'], sorted_data['avg_arousal_index_high'],
# ...

# %% [markdown]
# # End of script

# %% [markdown]
# **Authors: Naomi Baes and Chat GPT**
#
# *myenv (Python 3.11.9)*

# %% [markdown]
# # Plot Intensity Index

# %% [markdown]
# ### 5-year Intensity

# %%
#%run step4_plot_5-year_intensity-index_HIGH.py

# %%
#%run step4_plot_5-year_intensity-index_LOW.py

# %%
# %run step4_baseline_plot_5-year_intensity-index_BOTH.py
# Out:
# Successfully read data from CSV file.

# %% [markdown]
# ## all-year Intensity

# %%
# %run step4_baseline_plot_all-year_intensity-index_BOTH_SE.py
# Out:
# C:\Users\naomi\OneDrive\COMP80004_PhDResearch\RESEARCH\PROJECTS\3_evaluation+validation - ACL 2025\ICL\3_intensity\step4_baseline_plot_all-year_intensity-index_BOTH_SE.py:55: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-" (-> linestyle='-'). The keyword argument will take precedence.
#   # Add labels to the upper left corner
# C:\Users\naomi\OneDrive\COMP80004_PhDResearch\RESEARCH\PROJECTS\3_evaluation+validation - ACL 2025\ICL\3_intensity\step4_baseline_plot_all-year_intensity-index_BOTH_SE.py:55: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-" (-> marker='o'). The keyword argument will take precedence.
#   # Add labels to the upper left corner
# C:\Users\naomi\OneDrive\COMP80004_PhDResearch\RESEARCH\PROJECTS\3_evaluation+validation - ACL 2025\ICL\3_intensity\step4_baseline_plot_all-year_intensity-index_BOTH_SE.py:58: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-" (-> linestyle='-'). The keyword argument will take precedence.
#
# C:\Users\naomi\OneDrive\COMP80004_PhDResearch\RESEARCH\PROJECTS\3_evaluation+validation - ACL 2025\ICL\3_intensity\step4_baseline_plot_all-year_intensity-index_BOTH_SE.py:58: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o-" (-> marker='o'). The keyword argument will take precedence.
#
# C:\Users\naomi\OneDrive\COMP80004_PhDResearch\RESEARCH\PROJECTS\3_evaluation+validation - ACL 2025\ICL\3_intensity\step4_baseline_plot_all-year_intensity-index_BOTH_SE.py:99: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %% [markdown]
# # End of script

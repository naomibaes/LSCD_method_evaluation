# %% [markdown]
# # Statistical Analysis
#
# **Authors: Naomi Baes and Chat GPT**
#
# *myenv (Python 3.11.9)*

# %% [markdown]
# ## APD

# %%
# %run step5_APD_analysis_5-year.py

# %%
# %run step5_APD_analysis_all-year.py
# Out:
# Successfully read data from CSV file.
#              Term  APD_High   APD_Low
# 2      depression  0.124541  0.142760
# 1         anxiety  0.116645  0.118771
# 4  mental_illness  0.105596  0.104442
# 0          trauma  0.100123  0.113792
# 3   mental_health  0.088359  0.077146
# 5           abuse  0.062839  0.091571

# %% [markdown]
# ## MEM (low)

# %%
# %run step6_5-year_mem_analysis_low.py
# Out:
# c:\Users\naomi\anaconda3\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2238: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\naomi\anaconda3\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2238: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# Null Model Summary:
#                Mixed Linear Model Regression Results
# ...
# Model:            MixedLM Dependent Variable: avg_arousal_index_low
# No. Observations: 360     Method:             REML
# No. Groups:       6       Scale:              0.0087
# Min. group size:  60      Log-Likelihood:     328.5733
# Max. group size:  60      Converged:          Yes
# Mean group size:  60.0
# ----------------------------------------------------------------------
#              Coef.    Std.Err.       z       P>|z|    [0.025    0.975]
# ...

# %% [markdown]
# ## MEM (high)

# %%
# %run step6_5-year_mem_analysis_high.py
# Out:
# c:\Users\naomi\anaconda3\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2238: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\naomi\anaconda3\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2238: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# Null Model Summary:
#                Mixed Linear Model Regression Results
# ...
# Model:            MixedLM Dependent Variable: avg_arousal_index_high
# No. Observations: 360     Method:             REML
# No. Groups:       6       Scale:              0.0098
# Min. group size:  60      Log-Likelihood:     308.1017
# Max. group size:  60      Converged:          Yes
# Mean group size:  60.0
# -----------------------------------------------------------------------
#               Coef.    Std.Err.       z       P>|z|    [0.025    0.975]
# ...

# %% [markdown]
# # End of script

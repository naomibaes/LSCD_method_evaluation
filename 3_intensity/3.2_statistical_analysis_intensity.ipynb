# %% [markdown]
# # Statistical Analysis
#
# **Authors: Naomi Baes and Chat GPT**
#
# *myenv (Python 3.11.9)*

# %% [markdown]
# ## MEM (low)

# %%
# %run step6_baseline_all-year_mem_analysis_low.py
# Out:
# c:\Users\naomi\anaconda3\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2238: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# Null Model Summary:
#                Mixed Linear Model Regression Results
# ===================================================================
# Model:            MixedLM Dependent Variable: avg_arousal_index_low
# No. Observations: 36      Method:             REML
# No. Groups:       6       Scale:              0.0082
# Min. group size:  6       Log-Likelihood:     27.4003
# Max. group size:  6       Converged:          Yes
# Mean group size:  6.0
# ----------------------------------------------------------------------
#               Coef.    Std.Err.      z       P>|z|    [0.025    0.975]
# ----------------------------------------------------------------------
# Intercept     4.087       0.042    97.053    0.000     4.005     4.170
# Group Var     0.009       0.080
# ===================================================================
#
# ICC for 'target': 0.5292945169339959
# Simplified Model with Random Intercepts Summary:
#                Mixed Linear Model Regression Results
# ===================================================================
# Model:            MixedLM Dependent Variable: avg_arousal_index_low
# No. Observations: 36      Method:             REML
# No. Groups:       6       Scale:              0.0004
# Min. group size:  6       Log-Likelihood:     63.4540
# Max. group size:  6       Converged:          Yes
# Mean group size:  6.0
# --------------------------------------------------------------------
#                     Coef.   Std.Err.     z     P>|z|  [0.025  0.975]
# --------------------------------------------------------------------
# Intercept            4.206     0.042   99.123  0.000   4.122   4.289
# injection_ratio     -0.002     0.000  -22.976  0.000  -0.003  -0.002
# Group Var            0.011     0.346
# ===================================================================
#
# Random Effects Variance (Intercepts): 0.010567920764696476
# Residual Variance: 0.00044403130778047814
# c:\Users\naomi\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\naomi\anaconda3\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2201: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# c:\Users\naomi\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\naomi\anaconda3\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2201: ConvergenceWarning: Retrying MixedLM optimization with cg
#   warnings.warn(
# Random Slopes Model Summary:
#                  Mixed Linear Model Regression Results
# =======================================================================
# Model:              MixedLM  Dependent Variable:  avg_arousal_index_low
# No. Observations:   36       Method:              REML
# No. Groups:         6        Scale:               0.0002
# Min. group size:    6        Log-Likelihood:      58.6332
# Max. group size:    6        Converged:           No
# Mean group size:    6.0
# -----------------------------------------------------------------------
#                             Coef.  Std.Err.    z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------------
# Intercept                    4.206    0.024 173.371 0.000  4.158  4.253
# injection_ratio             -0.002    0.004  -0.564 0.573 -0.011  0.006
# Group Var                    0.003    0.087
# Group x injection_ratio Cov -0.000    0.014
# injection_ratio Var          0.000
# =======================================================================
#
#
# Model Comparisons:
# Simplified Model AIC: nan
# Simplified Model BIC: nan
# Random Slopes Model AIC: nan
# Random Slopes Model BIC: nan
#
# Best Model Selected Based on AIC/BIC:
#                  Mixed Linear Model Regression Results
# =======================================================================
# Model:              MixedLM  Dependent Variable:  avg_arousal_index_low
# No. Observations:   36       Method:              REML
# No. Groups:         6        Scale:               0.0002
# Min. group size:    6        Log-Likelihood:      58.6332
# Max. group size:    6        Converged:           No
# Mean group size:    6.0
# -----------------------------------------------------------------------
#                             Coef.  Std.Err.    z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------------
# Intercept                    4.206    0.024 173.371 0.000  4.158  4.253
# injection_ratio             -0.002    0.004  -0.564 0.573 -0.011  0.006
# Group Var                    0.003    0.087
# Group x injection_ratio Cov -0.000    0.014
# injection_ratio Var          0.000
# =======================================================================
# c:\Users\naomi\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\naomi\anaconda3\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2207: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\naomi\anaconda3\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2219: ConvergenceWarning: Gradient optimization failed, |grad| = 6.853982
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\naomi\anaconda3\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2238: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\naomi\anaconda3\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2262: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# Shapiro-Wilk test for normality (Best Model): Statistic=0.8940273523330688, p-value=0.0023522309493273497
# Levene’s test for homogeneity of variances (Best Model): Statistic=0.0005386268527702246, p-value=0.9815501210766373

# %%
#%run step6_5-year_mem_analysis_low.py

# %% [markdown]
# ## MEM (high)

# %%
# %run step6_baseline_all-year_mem_analysis_high.py
# Out:
# c:\Users\naomi\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# c:\Users\naomi\anaconda3\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2238: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\naomi\anaconda3\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2238: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# Null Model Summary:
#                Mixed Linear Model Regression Results
# ====================================================================
# Model:            MixedLM Dependent Variable: avg_arousal_index_high
# No. Observations: 36      Method:             REML
# No. Groups:       6       Scale:              0.0064
# Min. group size:  6       Log-Likelihood:     31.6729
# Max. group size:  6       Converged:          Yes
# Mean group size:  6.0
# -----------------------------------------------------------------------
#               Coef.    Std.Err.       z       P>|z|    [0.025    0.975]
# -----------------------------------------------------------------------
# Intercept     4.312       0.038    114.060    0.000     4.238     4.386
# Group Var     0.008       0.073
# ====================================================================
#
# ICC for 'target': 0.5386232336080002
# Simplified Model with Random Intercepts Summary:
#                Mixed Linear Model Regression Results
# ====================================================================
# Model:            MixedLM Dependent Variable: avg_arousal_index_high
# No. Observations: 36      Method:             REML
# No. Groups:       6       Scale:              0.0003
# Min. group size:  6       Log-Likelihood:     68.3763
# Max. group size:  6       Converged:          Yes
# Mean group size:  6.0
# ----------------------------------------------------------------------
#                   Coef.   Std.Err.      z      P>|z|   [0.025   0.975]
# ----------------------------------------------------------------------
# Intercept         4.207      0.038   110.545   0.000    4.133    4.282
# injection_ratio   0.002      0.000    23.631   0.000    0.002    0.002
# Group Var         0.009      0.324
# ====================================================================
#
# Random Effects Variance (Intercepts): 0.0085189420588569
# Residual Variance: 0.0003282207279184618
# c:\Users\naomi\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\naomi\anaconda3\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2201: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# c:\Users\naomi\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\naomi\anaconda3\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2201: ConvergenceWarning: Retrying MixedLM optimization with cg
#   warnings.warn(
# c:\Users\naomi\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\naomi\anaconda3\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2207: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\naomi\anaconda3\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2219: ConvergenceWarning: Gradient optimization failed, |grad| = 6.895266
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\naomi\anaconda3\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2238: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# c:\Users\naomi\anaconda3\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2262: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# Random Slopes Model Summary:
#                  Mixed Linear Model Regression Results
# =======================================================================
# Model:             MixedLM  Dependent Variable:  avg_arousal_index_high
# No. Observations:  36       Method:              REML
# No. Groups:        6        Scale:               0.0002
# Min. group size:   6        Log-Likelihood:      59.9872
# Max. group size:   6        Converged:           No
# Mean group size:   6.0
# -----------------------------------------------------------------------
#                             Coef.  Std.Err.    z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------------
# Intercept                    4.207    0.024 178.951 0.000  4.161  4.253
# injection_ratio              0.002    0.004   0.518 0.604 -0.006  0.010
# Group Var                    0.003    0.084
# Group x injection_ratio Cov -0.000    0.014
# injection_ratio Var          0.000
# =======================================================================
#
#
# Model Comparisons:
# Simplified Model AIC: nan
# Simplified Model BIC: nan
# Random Slopes Model AIC: nan
# Random Slopes Model BIC: nan
#
# Best Model Selected Based on AIC/BIC:
#                  Mixed Linear Model Regression Results
# =======================================================================
# Model:             MixedLM  Dependent Variable:  avg_arousal_index_high
# No. Observations:  36       Method:              REML
# No. Groups:        6        Scale:               0.0002
# Min. group size:   6        Log-Likelihood:      59.9872
# Max. group size:   6        Converged:           No
# Mean group size:   6.0
# -----------------------------------------------------------------------
#                             Coef.  Std.Err.    z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------------
# Intercept                    4.207    0.024 178.951 0.000  4.161  4.253
# injection_ratio              0.002    0.004   0.518 0.604 -0.006  0.010
# Group Var                    0.003    0.084
# Group x injection_ratio Cov -0.000    0.014
# injection_ratio Var          0.000
# =======================================================================
# Shapiro-Wilk test for normality (Best Model): Statistic=0.9176033735275269, p-value=0.010712129063904285
# Levene’s test for homogeneity of variances (Best Model): Statistic=0.001014536951209478, p-value=0.9746808851401658

# %%
#%run step6_5-year_mem_analysis_high.py

# %% [markdown]
# # End of script
